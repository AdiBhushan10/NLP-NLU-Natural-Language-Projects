# %% [markdown]
# ### Install Dependencies

# %%
import json
import pandas as pd, numpy as np

# %% [markdown]
# ### Convert JSON to Pandas DataFrame

# %%
with open('Customer_Search_Sessions_Text_Data.json', 'r', encoding='UTF-8') as file1:
    json_df = pd.DataFrame(json.loads(line) for line in file1)
#json.load(file1)    
json_df.head()
# Out:
#                                            query_arr  \
# 0                                     [water bottle]
# 1  [eau de source, nutella, huile d’olive, chou f...
# 2  [coffee crisp, coffee, kinder, beuno, salad, b...
# 3  [water, canned drinks, soda, hot dog buns, hot...
# 4                           [eau, jus de canneberge]
#
#                                         atc_item_arr  \
# 0                                       [20005571_C]
# 1  [20005571_C, 20436105_EA;20574189_EA, 20729461...
# 2  [20019964_C, 20050931_EA, NO PRODUCT, NO PRODU...
# 3  [20022126_C, 20375155_C, 20306687003_C, 207799...
# 4                           [20022126_C, NO PRODUCT]
#
#                                        timestamp_arr  \
# 0                                       [1631528381]
# 1   [1631756371, 1631756422, 1631756501, 1631756536]
# 2  [1631542818, 1631542869, 1631545955, 163154598...
# 3  [1631721943, 1631721964, 1631722025, 163172207...
# 4                           [1631736981, 1631736999]
#
#                               sessionid
# 0  5ef0c4fd-31ae-4b60-adc3-ee0cf645c812
# 1  50534a81-5abe-4b66-be56-c767ee28acfc
# 2  0f10758d-f4c6-4ec4-9a86-08e353a9c221
# 3  e60e1c97-a7fc-46d3-af58-cc2f3de4b2f9
# 4  bb672d6d-fddc-4a9e-a898-6bd3f4bc8e78

# %% [markdown]
# ## Problem Interpretations (w/ Assumptions)
#
# ### 1. Each row in dataset corresponds to user searches per session
# ### 2. User made multiple queries (reformulated one after another) to search for desired product; Query_Array column stores the list of queries (analogous to single word tokens) made consecutively within each session
# ### 3a. One interpretation is that the final query (last product in query_arr) is the correct product user was looking for i.e. last query results in add-to-cart event.
# ### 3b. With this assumption, we are to calculate similarity between each query in query_arr with the last query for each session as an attempt to quantify inter-query relationship
#
# ### OR
#
# ### 4. Other interpretation is that we calculate similarity between consecutive querries within each query_array per user session

# %% [markdown]
# ## ML Solution using Word Embedding -  To measure text similarity
# ##### Use Word2Vec python library with my own Vocabulary
# ##### (Limitation: Only words defined within my vocab can be analyzed; outside words/new vocab will result into error )

# %%
#! pip install --user --upgrade gensim

# %%
# 3 a&b. Comparing each query with last query for **Session 2, Row 3**
from gensim.models import Word2Vec
vocab = json_df.values[2][0]  # creating vocab
model = Word2Vec([vocab], min_count = 1)  # training model
score, sim, odd= [],[],[]
k = len(vocab)
for j in range(k):
    ls = model.wv.similarity(vocab[j],vocab[k-1])  # analyzing model
    #ls1 = model.wv.most_similar(vocab[j])
    #ls2 = model.wv.doesnt_match(vocab)
    score.append(ls)
    #sim.append(ls1)
    #odd.append(ls2)
print(score)
#print(sim)
#print(odd)
print(vocab)
# Out:
# [-0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['coffee crisp', 'coffee', 'kinder', 'beuno', 'salad', 'bacon']

# %%
# 4. Consecutive queries compared and similarity score produced for **Session 2, Row 3**
from gensim.models import Word2Vec
vocab = json_df.values[2][0]    # creating vocab
model = Word2Vec([vocab], min_count = 1)   # training model
score, sim = [],[]
k = len(vocab)
for j in range(k-1):
    ls = model.wv.similarity(vocab[j],vocab[j+1])  # analyzing model
    score.append(ls)
print(score)
print(vocab)
# Out:
# [0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['coffee crisp', 'coffee', 'kinder', 'beuno', 'salad', 'bacon']

# %%
# 3 a&b. Comparing each query with last query for *** all Sessions in dataset ***
from gensim.models import Word2Vec
for i in range(len(json_df)):
    vocab = json_df.values[i][0]  # creating vocab
    model = Word2Vec([vocab], min_count = 1)  # training model
    score, sim, odd= [],[],[]
    k = len(vocab)
    for j in range(k):
        ls = model.wv.similarity(vocab[j],vocab[k-1])  # analyzing model
        #ls1 = model.wv.most_similar(vocab[j])
        #ls2 = model.wv.doesnt_match(vocab)
        score.append(ls)
        #sim.append(ls1)
        #odd.append(ls2)
    print(score)
    #print(sim)
    #print(odd)
    print(vocab)
# Out:
# [1.0]
# ['water bottle']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['eau de source', 'nutella', 'huile d’olive', 'chou fleur']
# [-0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['coffee crisp', 'coffee', 'kinder', 'beuno', 'salad', 'bacon']
# [0.16918248, 0.08388674, 0.0024377787, -0.014110296, -0.11393685, 0.2188389, 0.054231673, -0.03758423, -0.04111742, 0.09312754, 0.079643264, 0.062814005, 0.21646474, 0.027162561, 0.09294609, 0.016276052, -0.059891753, -0.027792247, -0.11168494, -0.05228118, 0.06444459, -0.050787263, -0.13255474, 0.1416529, -0.01699349, -0.0011241268, -0.03421791, -0.07293519, -0.09941384, -0.01624264, 0.01690807, 0.096444026, 0.059555467, -0.001957709, 0.10862734, -0.14681098, 0.15155162, 0.04643498, 0.19564298, 0.099447004, -0.13832569, -0.095202714, -0.010680665, 1.0]
# ['water', 'canned drinks', 'soda', 'hot dog buns', 'hot dogs', 'milk', 'yogurt', 'cheddar cheese', 'nacho cheese', 'mozzarella', 'margarine', 'cucumbers', 'broccoli, cabbage & cauliflower', 'potatoes', 'celery', 'onions', 'garlic', 'canned tomatoes', 'apples', 'oranged', 'oranges', 'bananas', 'pears', 'apple sauce', 'juice', 'corn starch', 'rice', 'sugar', 'cream of tartar', 'instant yeast', 'yeast', 'ground beef', 'honey ham', 'chicken tenders', 'chicken broth', 'gold fish', 'pretzles', 'veggie straws', 'paper bowls', 'spoons', 'bleach', 'fabric softner', 'soap', 'soap refills']
# [-0.010839173, 1.0]
# ['eau', 'jus de canneberge']
# [0.09308152, 0.07963486, 0.06276734, 0.21617144, 0.027044848, 0.09291723, 0.016134718, -0.059876285, -0.027759008, -0.111670576, -0.052332718, -0.010830897, 1.0]
# ['case of water', 'grapefruit', 'grapefruit juice', 'chips', 'loads of japalano', 'loads of chips', 'milk', 'whipped cream', 'sauages', 'vienna sauages', 'too dogs', 'top dogs', 'lemon']
# [-0.052346755, -0.010839173, 1.0]
# ['water', 'butter', 'fruit packs']
# [0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'tide', 'garbage bags', 'pantene', 'polident', 'polident 3 minute', 'bacon']
# [-0.14746797, -0.052346755, -0.11164204, -0.027667694, -0.059876293, 0.0161488, 0.09297204, 0.027048562, 0.21617144, 0.06286195, 0.07963486, 0.09310115, -0.04120609, -0.03769852, 0.05434531, 0.2188547, -0.11398096, -0.014421888, 0.0024715287, 0.08402356, 0.06440437, -0.050813258, -0.13267727, -0.0019323195, -0.095387675, -0.13839911, 0.09942857, 0.19543621, 0.04622132, 0.15162764, -0.010839173, 1.0]
# ['water', 'orange juice', 'apple juice', 'pepperoni', 'salami', 'weiner', 'hot dog', 'eggs', 'dairy & eggs', 'hashbrowns', 'lettuce', 'ginger', 'bread', 'buns', 'chips', 'chip dip', 'waffles', 'cheese slices', 'cookies', 'kraft dinner', 'tea', 'chocloate syrup', 'milk', 'oreo sandwich', 'popsicle', 'fuzzy peach popsicle', 'rice', 'salt fish', 'ackee', 'geen onion', 'garlic', 'tums']
# [0.07977276, 0.062845565, 0.21615034, 0.027039941, 0.09301227, 0.016135858, -0.05984097, -0.027639696, -0.11159426, -0.052311253, -0.01088622, 0.99999994]
# ['water', 'epsom salts', 'garlic', 'cotton balls', 'cotton puffs', 'jumbo puffs', 'granola bars', 'simply orange', 'absorbent puffs', 'absorbent', 'face cleaner wipes', 'face cleaner']
# [0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'coffee', 'coffee mate', 'tide pods', 'downy', 'fabric conditioner', 'polident', 'hair colour']
# [0.21617144, 0.0272738, 0.092917226, 0.01613473, -0.059876285, -0.027750367, -0.111670576, -0.052346755, -0.010839181, 1.0]
# ['water', 'juice', 'bread', 'hashbrown', 'fruit cups', 'vitamin c', 'apples', 'tylenol', 'advil cold and flu', 'advil']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['pure life', 'gatorade', 'powerade', 'power']
# [1.0]
# ['molson']
# [1.0]
# ['water']
# [1.0]
# ['water']
# [1.0]
# ['water']
# [0.21883667, -0.052346755, -0.11167108, -0.027750367, -0.059876293, 0.016134718, 0.09291723, -0.010839173, 0.027066018, 0.0628508, 0.07970877, 0.09314463, -0.041253414, -0.037719578, 0.054333676, 0.21614, 1.0]
# ['water', 'gatorade', 'bread', 'dempster', 'veggie dogs', 'basil', 'tissue', 'flour', 'horseradish', 'cashew milk', 'rice milk', 'natura', 'kimchi', 'nom shin', 'shin', 'aveeno balm', 'silk']
# [0.21883667, -0.052346755, -0.11167108, -0.027750367, -0.059876293, 0.016134718, 0.09291723, -0.010839173, 0.027066018, 0.0628508, 0.07970877, 0.09314463, -0.041253414, -0.037719578, 0.054333676, 0.21614, 1.0]
# ['water', 'montellier', 'egg whites', 'spinach', 'chickpea', 'avocado', 'sweet potatoes', 'butternut squash', 'cous cous', 'couscous', 'greek yougurt', 'lettuce', 'beet', 'cookies', 'crackers', 'apple', 'rice cakes']
# [-0.010839173, 1.0]
# ['water', 'liberte']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', '7 up', "po'", 'pop']
# [-0.11397442, -0.05230291, -0.111207075, -0.027761096, -0.059551895, 0.016269222, 0.092917286, 0.027070016, 0.21614805, 0.06285532, 0.079646334, 0.09310166, -0.04125226, -0.03768483, 0.05444585, 0.21875507, -0.010823835, 0.99999994]
# ['spring water', 'borax', 'manuka', 'waffles', 'garbage bags', 'organic pasta', 'organic molisana', 'organic vita sana', 'dish soap', 'pickels', 'silver hills', 'sprouted wheat', 'salami', 'figs', 'wine', 'natural spring water', 'black label', 'banana']
# [0.07977276, 0.062845565, 0.21615034, 0.027039941, 0.09301227, 0.016135858, -0.05984097, -0.027639696, -0.11159426, -0.052311253, -0.01088622, 0.99999994]
# ['water case', 'masks', 'facial tissue', 'qtips', 'cotton swabs', 'cappuccino', 'disinfecting wipes', 'lysol', 'brocolli', 'tomatoes', 'ice tea', 'prune juice']
# [0.21617144, 0.0272738, 0.092917226, 0.01613473, -0.059876285, -0.027750367, -0.111670576, -0.052346755, -0.010839181, 1.0]
# ['water', 'sangria', 'boisson sangria', 'cheese', 'buttermilk', 'cucumbers', 'duncan hinea', 'duncan hines', 'chips', 'cake mix']
# [0.21883667, -0.052346755, -0.11167108, -0.027750367, -0.059876293, 0.016134718, 0.09291723, -0.010839173, 0.027066018, 0.0628508, 0.07970877, 0.09314463, -0.041253414, -0.037719578, 0.054333676, 0.21614, 1.0]
# ['water', 'wchips', 'chips', 'kettle chips', 'eggs', 'large eggs', 'wraps', 'buns', 'garlic bread', 'garlic loaf', 'burgers', 'smokies', 'hotdog buns', 'tostitos', 'ciabata', 'salami', 'sharp cheddar']
# [-0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'milk', 'milk 2%', 'pepperettes', 'crave', 'reese']
# [-0.11397442, -0.05230291, -0.111207075, -0.027761096, -0.059551895, 0.016269222, 0.092917286, 0.027070016, 0.21614805, 0.06285532, 0.079646334, 0.09310166, -0.04125226, -0.03768483, 0.05444585, 0.21875507, -0.010823835, 0.99999994]
# ['water', 'crackers', 'stone wheat', 'ritz', 'maia', 'maria', 'ichiban', 'intant noodles', 'macaroni & cheese', 'corn flakes', 'rice krispies', 'juice boxes', 'rice cereal', 'potatoe', 'bananas', 'ibprofan', 'acetaminophen extra strength 500mg', 'dish soap']
# [0.21617144, 0.0272738, 0.092917226, 0.01613473, -0.059876285, -0.027750367, -0.111670576, -0.052346755, -0.010839181, 1.0]
# ['nestles water', 'kale chard', 'organic blueberries', 'organic bananas', 'arla cream cheese', 'natures path heritage flakes', 'eden pizza sauce', 'pizza sauce', 'ladies underwear', 'baleine sea salt']
# [0.0643779, -0.052346755, -0.111661434, -0.027750367, -0.05984619, 0.016197931, 0.09291723, 0.027058955, 0.21619494, 0.0628508, 0.07963486, 0.09310115, -0.041253414, -0.03769949, 0.054339662, 0.21884768, -0.11398096, -0.014373494, 0.0024360362, 0.08404717, -0.010832924, 1.0]
# ['water', 'taco', 'canadian ice cream', 'turky sasage', 'turky sasage pc', 'noodles', 'sasala', 'salsa', 'soyasorce', 'soya sorce', 'oil', 'apple cider vineger', 'canadian apple cider vineger', 'always', 'always no wings', 'wipes', 'baby wipes', 'face clener', 'face clener spray', 'face clener spry', 'face clener liduid', 'face clener liguid']
# [-0.052346755, -0.010839173, 1.0]
# ['water', 'instant coffee', 'chicken']
# [-0.010839173, 1.0]
# ['water', 'oatmeal']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'juice box', 'hand soap', 'hand soap foaming', '6 inch red velvet cake']
# [0.099371694, -0.05235284, -0.111642584, -0.027750367, -0.05994034, 0.01612062, 0.092756376, 0.027053455, 0.21617144, 0.062751696, 0.07963486, 0.09309135, -0.041253414, -0.037783913, 0.05430627, 0.21874553, -0.11398096, -0.014488164, 0.0023989887, 0.08403174, 0.06434413, -0.050830644, -0.13276802, -0.0019527591, -0.0954183, -0.1384161, -0.010839173, 1.0]
# ['water', 'potato patties', 'breakfast potatos', 'clamatoe', 'clamato, extra spicy', 'clam juice', 'clamchowder', 'muffin mix', 'sweetner', 'chip dip', 'lays', 'cookies lemmon', 'spinage', 'bread', 'ground beef regular', 'beef ground', 'soup mix', 'spring greens', 'spinach', 'cheese', '10', 'cola zero', 'ice tea', 'sugar', 'pc sugar substitute', 'date squares', 'bacon', 'hash browns']
# [0.0643779, -0.052346755, -0.111661434, -0.027750367, -0.05984619, 0.016197931, 0.09291723, 0.027058955, 0.21619494, 0.0628508, 0.07963486, 0.09310115, -0.041253414, -0.03769949, 0.054339662, 0.21884768, -0.11398096, -0.014373494, 0.0024360362, 0.08404717, -0.010832924, 1.0]
# ['water', 'toliet paper', 'paper towel', 'paper', 'wipes', 'bananas', 'chicken', 'parmesan & hard cheese', 'hard cheese', 'salad', 'arugala', 'cucumbers', 'kale crackers', 'turkey', 'avocado', 'kiwi', 'hemp', 'spinach', 'apples', 'hummus', 'baby carrots', 'seaweed']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'chips', 'salt and vinegar chips', 'popcorn', 'dill']
# [-0.010839173, 1.0]
# ['water', 'coke']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'coca cola', 'chicken breast', 'pork chops']
# [0.21883667, -0.052346755, -0.11167108, -0.027750367, -0.059876293, 0.016134718, 0.09291723, -0.010839173, 0.027066018, 0.0628508, 0.07970877, 0.09314463, -0.041253414, -0.037719578, 0.054333676, 0.21614, 1.0]
# ['natural spring water case', 'blueberries', 'caesar dressing', 'healthy skin anti wrinkle cream', 'healthy skin face lotion', 'soft & thick toilet paper, 12 rolls= 24', 'two scoops raisin bran cereal', 'ziploc', 'lettuce', 'granulated white sugar', 'package of coconut', 'unsweetened coconut', '14 grains whole wheat bread', 'tide laundry detergent', 'coffee pods', 'chicken broth', 'european wieners']
# [-0.037713584, -0.041253414, 0.093107, 0.07963486, 0.06287837, 0.21617144, 0.027057461, 0.09291723, 0.016169284, -0.059876293, -0.027739404, -0.11166717, -0.052346755, -0.010839173, 1.0]
# ['water', 'banana', 'lime yogurt', 'strawberry', 'pc strawberries', 'bagels', 'silver hills', 'chocolate soy', 'bread', 'cheese', 'cheese slices', 'hummus', 'carrots', 'cucumber', 'yogurt greek']
# [0.0628508, 0.2161742, 0.027057461, 0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839172, 1.0]
# ['water', 'beef broth', 'patotes', 'potatoes', 'ground beef', 'olive oil butter', 'breakfast sausage', 'breakfast patty', 'yoplait', 'mandarin', 'fruit cup']
# [0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'egg whites', 'original smokies', 'gillette', 'almonds', 'halibut', 'dishwashing']
# [0.084045656, -0.052344862, -0.11166299, -0.027744237, -0.05982618, 0.016208807, 0.09292351, 0.02704238, 0.21618979, -0.0108396895, 0.06285211, 0.09310338, -0.0412475, -0.037685502, 0.054319717, 0.2188576, -0.11397762, -0.0143875675, 0.0024422402, 0.07963361, 1.0]
# ['water', 'chicken', 'cheddar', 'gluten free bagels', 'gluten free pizza', 'tofu', 'bok choy', 'rice', 'broccoli', 'peppers', 'vegetables', 'stir fry', 'julienne carrots', 'egg noodle', 'chicken thigh', 'andalou', 'frozen peaches', 'frozen strawberries', 'milk', 'orang', 'orange juice']
# [0.13967735, 0.19553556, 0.09955836, -0.13826479, -0.095470764, -0.0018574498, -0.13249594, -0.050722733, 0.06440898, 0.08400916, 0.0024616993, -0.013976883, -0.11386031, 0.21892862, 0.054690752, -0.03747197, -0.041216712, 0.09354137, 0.080422334, 0.06289952, 0.2163026, 0.027068006, 0.0930191, 0.016535113, -0.0597465, -0.027766688, -0.111106135, -0.052010626, 0.046494298, 0.15202917, -0.14737312, -0.068305485, 0.024365041, 0.14115576, 0.054191306, -0.049716275, 0.086446404, 0.17212673, 0.12397715, -0.050560288, 0.11336781, 0.0382068, 0.05042612, -0.089359194, -0.13007402, 0.1086663, 0.07721865, 0.16936529, -0.016542874, -0.00054476154, -0.03408292, -0.07282405, -0.09937286, -0.016113847, 0.016936373, 0.096596636, 0.14194797, 0.05939931, -0.010826688, 0.99999994]
# ['water', 'snack bags', 'toilet paper', 'paper towel', 'ketchup', 'mustard', 'kraft dinner', 'gold fish', 'ham', 'canned corn', 'hashbrowns', 'cheddar soup', 'marble cheese', 'oil', 'becel', 'chicken', 'chicken thighs', 'flank steak', 'coleslaw', 'romaine', 'm and m', 'smarties', 'fruit snacks', 'welches', 'broccoli', 'delissio', 'eggs', 'turkey', 'mini bagels', 'ice burg', 'iceburg', 'green leaf lettuce', 'crest', 'lemonade', '7 up', 'diet', 'sprite', 'gatorade', 'wheat crunch', 'honey', 'dove soap', 'dove sensitive skin', 'garlic powder', 'onion powder', 'corn starch', 'kool aid', 'jube jube', 'miss vickys', 'ichiban', 'sour cream', 'lactose free', 'green pepper', 'green onion', 'cauliflower', 'pepperoni', 'grimms', 'chicken wings', 'ranch', 'wavy chips', 'lysol wipes']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'pizza pocket', 'buns', 'chips', 'pepperoni']
# [0.0643779, -0.052346755, -0.111661434, -0.027750367, -0.05984619, 0.016197931, 0.09291723, 0.027058955, 0.21619494, 0.0628508, 0.07963486, 0.09310115, -0.041253414, -0.03769949, 0.054339662, 0.21884768, -0.11398096, -0.014373494, 0.0024360362, 0.08404717, -0.010832924, 1.0]
# ['nestle water', 'alcohol', 'baby wipes', 'toilet paper', 'kettle', 'dish soap', 'oats', 'butter', 'crackers', 'cream cheese', 'vega', 'avocado', 'newmans', 'carrots', 'glutinous rice', 'rice', 'carnation milk', 'evaporated milk', 'potatoes', 'bacon', 'corn', 'lays']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'bai', 'barista soy', 'almond milk']
# [1.0]
# ['aquafina']
# [0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['aquafina', 'coca cola', 'ginger ale', 'quaker', 'dark chocolate granola bars', 'air fresheners', 'air fresheners stick on']
# [-0.04126148, 0.09310115, 0.079644546, 0.0628508, 0.21621574, 0.027057461, 0.09291723, 0.016134718, -0.05987265, -0.027750367, -0.11167732, -0.052332763, -0.010839173, 1.0]
# ['water', 'chicken breast', 'chicken drumstivk', 'grapes', 'jam', 'smoothy mix', 'smoothy', 'cake', 'beef jerky', 'bacon', 'corn', 'cereal', 'creamer', 'milk']
# [0.027057461, 0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['bottled water case', 'diet coke case', 'pc sparkling lemonade', 'arizona green tea', 'english muffin', 'brussel sprouts', 'mennonite style farmers sausage', "campbell's vegetable soup", 'beef broth']
# [-0.037713584, -0.041253414, 0.093107, 0.07963486, 0.06287837, 0.21617144, 0.027057461, 0.09291723, 0.016169284, -0.059876293, -0.027739404, -0.11166717, -0.052346755, -0.010839173, 1.0]
# ['kitkat', 'aero bar, king size case', 'aero bar', 'bread', 'macaroni', 'ice cream', 'ice cream cone', 'tomato basil soup', 'tomato soup', 'soup', 'juice', 'juice club', 'shelf stable juices', 'syrup', 'coffee']
# [-0.052346755, -0.010839173, 1.0]
# ['eska', 'dascani', 'dried mango']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['becks', 'dealcoholised sparkling wine, white', 'dealcoholised beer', 'no alcohol beer']
# [0.21617144, 0.0272738, 0.092917226, 0.01613473, -0.059876285, -0.027750367, -0.111670576, -0.052346755, -0.010839181, 1.0]
# ['becks', 'baby gourmet', 'ziploc', 'tomato', 'mini hummus', 'hummus', 'bean salad', 'quinoa salad', "shepherd's pie", 'chicken']
# [-0.050813857, -0.05230651, -0.1114851, -0.027741695, -0.0596291, 0.016301202, 0.092931725, 0.027287314, 0.2161828, 0.06284849, -0.010739859, 0.0796357, -0.041259706, -0.037470493, 0.054340623, 0.21899799, -0.1139749, -0.0141835315, 0.0024410586, 0.08407959, 0.06438949, 0.09305835, 1.0]
# ['lean', 'vicks', 'texas toast', 'grape', 'powerade', 'simply ageless', 'simply', '205', '210', 'nail polish remover', 'acetone', 'polish remover', 'quo', 'quick dry', 'sally hansen', 'sally hansen insta', 'insta dri', 'top coat', 'french', 'hamburger bun', 'ballpark classics limited edition 8 hamburger buns', 'tomato', 'red onion']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['lean cuts wet', 'tortilla & wraps', 'rib', 'cherry coke']
# [0.099371694, -0.05235284, -0.111642584, -0.027750367, -0.05994034, 0.01612062, 0.092756376, 0.027053455, 0.21617144, 0.062751696, 0.07963486, 0.09309135, -0.041253414, -0.037783913, 0.05430627, 0.21874553, -0.11398096, -0.014488164, 0.0023989887, 0.08403174, 0.06434413, -0.050830644, -0.13276802, -0.0019527591, -0.0954183, -0.1384161, -0.010839173, 1.0]
# ['mama', 'passata', 'iogo', 'yogurt', 'garlic peas', 'coconut miracle oil', 'make up remover', 'make up remover micellar', 'make up micellar', 'q tips', 'nesquik', 'mushroom knorr', 'mushroom tablet', 'mushroom', 'mushroom broth', 'mushroom cubes', 'knorr cubes', 'cranberry', 'cranberry sunrype', 'toothpaste crest', 'tofu', 'celery', 'dill pickles', 'mayonnaise light 1 2 fat', 'parmesan', 'parmesan pc', 'taco seasoning', 'salsa']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['bottled water', 'calmag', 'sisu cal', 'sisu']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'sugar cubes', 'romaine', 'mens diapers', 'topopthpaste']
# [1.0]
# ['bière sans alcool']
# [-0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['naya', 'framboise', 'bleuets', 'dainty', 'fiz dainty', 'riz dainty']
# [0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['biere', 'fromage cottage 1%', 'fromage allege', 'fromage', 'pois chiche', 'hummus', 'napkin']
# [1.0]
# ['water']
# [1.0]
# ['water']
# [1.0]
# ['eau']
# [-0.010839173, 1.0]
# ['water', 'shampoo']
# [-0.010839173, 1.0]
# ['water', 'ground beef rolls']
# [-0.010839173, 1.0]
# ['eau', 'berska']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'paper paltes', 'paper plates', 'royal plates']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['bottled water', 'brita filters', 'chicken stock', 'juice', 'butter']
# [0.19537023, -0.052302137, -0.1108251, -0.02772966, -0.059861604, 0.01633822, 0.09324668, 0.027701491, 0.21613, 0.06284952, 0.079663746, 0.09369284, -0.040945526, -0.010441422, -0.037528288, 0.21919294, -0.11391056, -0.013988867, 0.0024561626, 0.08440935, 0.06451626, -0.050271325, -0.13252832, -0.001503757, -0.09545748, -0.13840753, 0.09946191, 0.054321274, 1.0]
# ['eau', 'oeufs', 'oeuf', 'brocolis', 'choux fleur', 'poulet', 'ficello', 'oasis', 'nutri grains', 'ritz', 'cristie', 'minces aux légumes', 'poivrons', 'choux bruxelle', 'salade de poulet', 'raisins verts', 'betty crocker', 'betty crocker purée', 'pommes de terre en purée', 'cottage', 'café', 'café en grains', 'café le choix du président', 'café van houtte', 'crème glacée', 'crème glacée caramel', 'melon', 'framboises', 'haricots']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'eggs', 'slice cheese', 'toilet paper']
# [0.21617144, 0.0272738, 0.092917226, 0.01613473, -0.059876285, -0.027750367, -0.111670576, -0.052346755, -0.010839181, 1.0]
# ['water', 'phapdelphia cheese', 'philadelphia cheese', 'pasta sauce', 'chicken parmesan', 'chicken parmigiana', 'cottage cheese', 'salad kit', 'caesar salad', 'organic strawberry']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'mortadella', 'provolone cheese', 'crackers', 'milk']
# [-0.010839173, 1.0]
# ['bottled water', 'bleach']
# [0.0628508, 0.2161742, 0.027057461, 0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839172, 1.0]
# ['water', 'coke', 'grapes', 'gogo', 'gogo apple sauce', 'cookies', 'carrots', 'pasta', 'pasta sauce', 'meat ball', 'meatballs']
# [-0.050813857, -0.05230651, -0.1114851, -0.027741695, -0.0596291, 0.016301202, 0.092931725, 0.027287314, 0.2161828, 0.06284849, -0.010739859, 0.0796357, -0.041259706, -0.037470493, 0.054340623, 0.21899799, -0.1139749, -0.0141835315, 0.0024410586, 0.08407959, 0.06438949, 0.09305835, 1.0]
# ['water', 'caffeine free diet coke', 'diet sprite', 'sprite', 'diet coke', 'cplus', 'c plus', 'c plus orange soda', 'pop', 'pre popped', 'c plus pop', 'orange soda', 'diet pop', 'diet soda', 'soda', 'sliced ham', 'country harvest bread', 'dempsters bread', 'no name peanut butter', 'lysol toilet bowl cleaner', 'dishwasher tabs', 'frozen macaroni', 'stouffers']
# [-0.016267544, -0.11394205, 0.21881685, 0.054427225, -0.037773144, -0.041250158, 0.0931268, 0.08022184, 0.21612708, -0.010667748, 0.027050594, 0.092983276, 0.01610603, -0.059676766, -0.027739761, -0.11165262, -0.05197975, -0.01416579, 0.002723972, 0.08424263, 0.06462405, 0.016965894, 0.096397795, 0.14188349, 0.059505314, 0.10854239, -0.14745992, 0.15171227, 0.046336163, 0.19529124, 0.09950243, -0.13814098, -0.095133476, -0.0019077666, -0.13259402, -0.050722644, 0.06293594, 1.0]
# ['water', 'pepsi', 'gingerale', 'perier', 'carbonated water', 'salami', 'balogna', 'buns', 'kaiser buns', 'chicken noodle soup', 'lunch snacks', 'bear paws', 'chips', 'grapes', 'nectarine', 'ceasar salad', 'kielbassa', 'kielbassa coil', 'bread', 'bananas', 'juice box', 'kolbassa', 'chicken broth', 'onions', 'potatoes', 'toilet paper', 'eggs', 'rice', 'frozen vegetables', 'pickles', 'vachon', 'cheese', 'green onion', 'cat litter', 'mirin', 'chinese cooking wine', 'pierogies', 'perogies']
# [-0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'corn', 'carrots', 'fruit tray', 'breakfast', 'tea biscut']
# [-0.010839173, 1.0]
# ['bottled water', 'chicken thighs']
# [0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'black diamond combos', 'cheerios', 'janes', 'robin hood flour', 'ham steak', 'hot chocolate', 'keurig']
# [-0.010839173, 1.0]
# ['water', 'dishwasher']
# [-0.04126148, 0.09310115, 0.079644546, 0.0628508, 0.21621574, 0.027057461, 0.09291723, 0.016134718, -0.05987265, -0.027750367, -0.11167732, -0.052332763, -0.010839173, 1.0]
# ['water bottle', 'oats', 'chia seeds', 'cabbage', 'green peppers', 'cooking spinach', 'banana', 'ice burg lettice', 'ice burg', 'lettuce', 'eska', 'black beans', 'no name', 'no name beans']
# [0.0628508, 0.2161742, 0.027057461, 0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839172, 1.0]
# ['water', 'parchment paper', 'berry', 'fruit', 'ground beef', 'sugar free snack', 'sugar free granola bar', 'eggs', 'potato', 'pasta sauce', 'pasta noodles']
# [0.05954211, -0.14754918, 0.15183392, 0.046357054, 0.19550453, 0.09966662, -0.13817698, -0.095459595, -0.0020212904, -0.13237685, -0.05072396, 0.064502284, 0.08444859, 0.0025846767, -0.013892198, 0.2190883, -0.010427114, 0.05446244, -0.037706528, -0.04110916, 0.09341895, 0.07984346, 0.06324241, 0.2166588, 0.027809255, 0.0930249, 0.016114095, -0.059413917, -0.027680159, -0.11169813, -0.052017666, 0.10898302, -0.11386645, 0.05963389, -0.050161626, 0.20477673, 0.02880946, -0.117424496, 0.042105988, -0.004507065, -0.019415108, 0.13993694, 0.023959, 0.1405757, 0.05371525, -0.049685027, 0.08604124, 0.172445, 0.123645246, 0.11337644, 0.09628738, 0.038342535, 0.050917972, -0.08970757, -0.068471014, -0.13085243, 0.07689327, 0.16932273, -0.017235853, -0.00081452425, -0.034050692, -0.0725281, -0.0991752, -0.016020803, 0.017321175, 0.14210464, 1.0]
# ['water', 'bread', 'bagel', 'pogo', 'mr.noodles', 'english muffin', 'luncheon meat', 'lunch meat', 'sliced cheese', 'ham', 'apple', 'banana', 'juice', 'juice box', 'extra strenght back muscle', 'back relief', 'back muscle pain', 'white bread', 'brown bread', 'water melon', 'fruits', 'mcintosh apples', 'juice boxes', 'fruit juice boxes', 'carrots', 'cereals', 'cereals vanila rice krispies', 'chicken', 'mayo', 'cheese and crackers', 'lactose free milk', 'honey', 'coffee cups', 'coffee paper cups', 'coffee cups with lids', 'paper cups with lids', 'toilet paper', 'paper towels', 'matches', 'take out coffee cups and lids', 'paper cups', 'paper mugs', 'paper', 'paper cups lids', 'coffee cups with litds', 'pepercoffee cups with litds', 'peper coffee cups with litds', '120z coffee cup w lid', '120z coffee cup', '120z coffee cup with lid', '120oz coffee cup with lid', '120oz coffeepaper cup with lid', '120oz coffee paper cup with lid', '12oz coffee cup with lid', '12oz coffee cup', '12oz coffee', '12oz paper cupscoffee', '12oz paper cups', '12oz paper cups eith lids', '12oz paper cups with lids', '12oz coffee cups with lid', 'cups', 'cups with lids', 'cups,plates', 'cup', 'paper cup', 'paper plate']
# [1.0]
# ['real canadian water']
# [1.0]
# ['water']
# [1.0]
# ['water']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'yellow beans', 'canned', 'soup']
# [0.054400526, -0.03770622, -0.040908147, 0.093054116, 0.07960558, 0.0628729, 0.21611355, 0.027098363, 0.09322798, 0.016132005, -0.059853017, -0.027568284, -0.111667946, -0.0523743, -0.010798492, 1.0]
# ['water', 'eggs', 'milk', 'mazola', 'olive oil', 'extra virgin olive oil', 'pampers', 'aveeno', 'aveeno baby', 'yogurt', 'igo yogurt', 'iogo yogurt', 'pineapple', 'watermelon', 'blueberries', 'kiwi']
# [-0.13296388, -0.05194539, -0.11067127, -0.027848762, -0.059580136, 0.016495168, 0.093052045, 0.028975924, 0.2159744, 0.06294906, 0.08027963, 0.093509614, -0.04124534, -0.03748921, 0.054107282, 0.21842249, -0.113898635, -0.014165592, 0.002939547, 0.084351204, 0.06543157, -0.050264582, -0.010558398, 1.0]
# ['water', 'pop', 'coke', 'lattice', 'fruits and vegetables', 'lettuce and tomatoes', 'eggs', 'milk', 'cream', 'red bull', 'crush', 'chips', 'snack bars', 'hotdog buns', 'burger buns', 'wieners', 'lunch mate', 'brownies', 'cake', 'drinks', 'laundry detergent', 'fabric softener', 'sellet', 'vegetables']
# [-0.052346755, -0.010839173, 1.0]
# ['water', 'axe body wash', 'barbisol']
# [0.21883667, -0.052346755, -0.11167108, -0.027750367, -0.059876293, 0.016134718, 0.09291723, -0.010839173, 0.027066018, 0.0628508, 0.07970877, 0.09314463, -0.041253414, -0.037719578, 0.054333676, 0.21614, 1.0]
# ['water', 'coffee mate', 'philidelphia', 'coffeemate', 'nescafe', 'oatmeal', 'ground beef', 'cucumber', 'red oniion', 'onions', 'hawkins cheezies', 'sour dough', 'ktchup', 'ketchup', 'lettuce', 'ice cream', 'chapmans ice cream']
# [-0.052346755, -0.010839173, 1.0]
# ['case water', 'bagels', 'bread']
# [0.16918248, 0.08388674, 0.0024377787, -0.014110296, -0.11393685, 0.2188389, 0.054231673, -0.03758423, -0.04111742, 0.09312754, 0.079643264, 0.062814005, 0.21646474, 0.027162561, 0.09294609, 0.016276052, -0.059891753, -0.027792247, -0.11168494, -0.05228118, 0.06444459, -0.050787263, -0.13255474, 0.1416529, -0.01699349, -0.0011241268, -0.03421791, -0.07293519, -0.09941384, -0.01624264, 0.01690807, 0.096444026, 0.059555467, -0.001957709, 0.10862734, -0.14681098, 0.15155162, 0.04643498, 0.19564298, 0.099447004, -0.13832569, -0.095202714, -0.010680665, 1.0]
# ['natural spring', 'club soda', 'apple cider vinegar', 'apple juice', 'gusher', 'krave', 'ben and jerry', 'no name chips', 'goldfish', 'freezer bag', 'bagel', 'bagel cheese', 'bread', 'banana', 'berries', 'watermelon', 'bear paw', 'alphaghetti', 'beefaroni', 'kolbassa', 'fruit cup', 'tide', 'bounty', 'yup', 'yop', 'cucumber', 'janes', 'pc chicken', 'spring roll', 'tortilla wraps', 'lettuce', 'bacon bits', 'ranch', 'caesar', 'turkey', 'ready crisp', 'eggs', 'breakfast sausage', 'tomato', 'hashbrown', 'cavendish', 'hash brown', '9 minute', 'mccain']
# [-0.050813857, -0.05230651, -0.1114851, -0.027741695, -0.0596291, 0.016301202, 0.092931725, 0.027287314, 0.2161828, 0.06284849, -0.010739859, 0.0796357, -0.041259706, -0.037470493, 0.054340623, 0.21899799, -0.1139749, -0.0141835315, 0.0024410586, 0.08407959, 0.06438949, 0.09305835, 1.0]
# ['water', 'strawberries', 'made good pizza', 'grapes', 'bagel bites', 'lime chips', 'salsa', 'corn pops', 'turkey bacon', 'bacon', 'aaples', 'salad dressing', 'peppers', 'tomatoes', 'snap peas', 'nectarines', 'ham', 'salad', 'raspberries', 'muffins', 'avacado', 'cereal', 'life']
# [-0.09542728, -0.052369136, -0.11165976, -0.027750367, -0.059878193, 0.016119083, 0.09291723, 0.027040757, 0.21617271, 0.06285131, 0.07961583, 0.09310115, -0.04126677, -0.037717108, 0.054299466, 0.21883953, -0.113973886, -0.014436705, 0.0023975396, 0.0840289, 0.064345285, -0.050813258, -0.13277607, -0.0019484955, -0.010839173, 1.0]
# ['water', 'rice', 'mr noodles', 'asago dip', 'meat', 'stir fry', 'stir fry strips', 'beef stewing cubes, boneless', 'pineappl', 'tortilla', 'cashews', 'chicken kabobs', 'chicken breast', 'popcicles', 'freezies', 'cheese', 'apples', 'cucumber', 'instabt coffee', 'pringle cups', 'pringles', 'granola bars', 'granola bars caramel nut', 'orange joice', 'protein granola bars', 'yogurt']
# [0.0024360362, -0.052346755, -0.11165246, -0.027750367, -0.059813786, 0.016171485, 0.09291723, 0.027047977, 0.21617801, 0.0628508, 0.07963486, 0.09310115, -0.041253414, -0.037699, 0.054330662, 0.21884276, -0.11398096, -0.0143946875, -0.010839173, 1.0]
# ['water case', 'almond milk', 'milk', 'dill pickles', 'hot peppers', 'bell peppers', 'yop case', 'yop', 'yop yogurt', 'yops', 'fruit cups', 'juice boxes', 'raspberries', 'blueberries', 'bananas', 'ceasar dressing', 'ketchup', 'potatoes', 'chips', 'bread']
# [-0.03423771, -0.014336314, -0.113800794, 0.21878365, 0.05435562, -0.03770299, -0.041206516, 0.09331084, 0.07955845, 0.0628188, 0.2162662, 0.027297238, 0.09292492, 0.016160317, -0.059827145, -0.027611896, -0.11157284, -0.052225765, 0.0023566375, -0.010504705, 0.084122196, -0.05061937, -0.07281609, -0.09943468, -0.01626545, 0.016980924, 0.096194275, 0.14178456, 0.05946036, 0.10855298, -0.14740536, 0.1519192, 0.046487592, 0.19555926, 0.09977648, -0.1381227, -0.095433794, -0.0018573268, -0.13257986, 0.06456667, 1.0]
# ['water', 'eggs', 'bacon', 'fruit salad', 'eggos', 'waffles', 'thick waffles', 'front loops', 'froot loops cereal', 'orange juice', 'milk', 'jammers', 'turkey breast', 'salami', 'oranges', 'grapes', 'watermelon', 'canalope', 'bananas, bunch', 'strawberries', 'raspberries', 'lettuce & leafy vegetables', 'celery', 'broccoli', 'potatoes', 'canned corn', 'lean ground beef', 'pork chops', 'hot pockets', 'pizza pockets', 'lasagna', 'weiners', 'hot dogs', 'cheese slices', 'lime', 'lemon', 'cheese whiz', 'mini wheats', 'ketchup', 'syrup', 'mr. noodle']
# [-0.014417639, -0.05225071, -0.11148954, -0.027773924, -0.059638318, 0.01631432, 0.09289809, 0.027302168, -0.010728652, 0.21614625, 0.079655915, 0.09308225, -0.041265883, -0.03765665, 0.054369073, 0.21890432, -0.11396976, 0.063003704, 1.0]
# ['water', 'frozen vegetables', 'bread', 'kimchi noodles', 'pineapple can', 'carrots', 'icing sugar', 'sour cream', 'salt', 'pepper', 'trifle cake pan', 'trifle bowl', 'pizza pockets', 'choclate milk', 'facial tissue', 'eggs', 'cream cheese', 'cocoa', 'flour']
# [-0.014417639, -0.05225071, -0.11148954, -0.027773924, -0.059638318, 0.01631432, 0.09289809, 0.027302168, -0.010728652, 0.21614625, 0.079655915, 0.09308225, -0.041265883, -0.03765665, 0.054369073, 0.21890432, -0.11396976, 0.063003704, 1.0]
# ['water', 'juice boxes', 'juice boxes strawberry banana', 'tomatoes', 'cream cheese', 'chips', 'laundry soap', 'laundry detergent', 'white vinegar', 'peaches', 'bananas', 'plums', 'frozen berries', 'chicken wings', 'band aids', 'dish sponges', 'brita', 'potatoes', 'all purpose cleaner']
# [-0.11397442, -0.05230291, -0.111207075, -0.027761096, -0.059551895, 0.016269222, 0.092917286, 0.027070016, 0.21614805, 0.06285532, 0.079646334, 0.09310166, -0.04125226, -0.03768483, 0.05444585, 0.21875507, -0.010823835, 0.99999994]
# ['water', 'doritos', 'muffins', 'mini muffin', 'milk', 'egg', 'grapes', 'hot dog', 'nibs', 'beer', 'dino', 'garlic', 'red pepper', 'apples', 'gala apple', 'muffin', 'italiano', 'colgate kids']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'lunchable', 'koba', 'meat', 'hamburger']
# [0.027057461, 0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['yop', 'craquelins et biscuits', 'craquelins', 'jus', 'patte', 'poulet', 'poisson', 'eponge', 'mio']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['yop', 'épice bagel', 'bagel', 'fromage a la crème']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['yoplait', 'wraps', 'peas, beans & corn', 'canned corn', 'eggs']
# [0.0643779, -0.052346755, -0.111661434, -0.027750367, -0.05984619, 0.016197931, 0.09291723, 0.027058955, 0.21619494, 0.0628508, 0.07963486, 0.09310115, -0.041253414, -0.03769949, 0.054339662, 0.21884768, -0.11398096, -0.014373494, 0.0024360362, 0.08404717, -0.010832924, 1.0]
# ['yoplait', 'nescafe rich', 'peppers', 'green grapes', 'grapes', 'bleberries', 'blueberries', 'cream cheese', 'cream cheese strawberry', 'flour wraps', 'butter', 'gatorade', 'chicken strips', 'shredded cheese', 'sliced cheddar', 'milk', 'eggs', 'bread', 'pancakes', 'pots and pans', 'keurig', 'keurig single serve coffee maker']
# [0.09308152, 0.07963486, 0.06276734, 0.21617144, 0.027044848, 0.09291723, 0.016134718, -0.059876285, -0.027759008, -0.111670576, -0.052332718, -0.010830897, 1.0]
# ['yop', 'litière', 'chips', 'lays', 'ruffle', 'fromage marbre', 'blocs de fromage', 'brochette poulet', 'coke', 'coke canette', 'eau saveur', "caisse d'eau", "bouteille d'eau"]
# [-0.0688254, 0.06440032, 0.08404706, 0.0023803916, -0.01434113, -0.113879316, 0.21868971, 0.054582536, -0.03783117, -0.04136382, 0.080107585, -0.010939218, 0.06311106, 0.21645194, 0.027141362, 0.09332609, 0.01666104, -0.05963833, -0.027535552, -0.11147573, -0.051756773, -0.050899938, 0.09337528, -0.13244265, 0.01733026, -0.13078067, 0.07680347, 0.16941091, -0.016605316, -0.0009780205, -0.03430803, -0.07283108, -0.0992731, -0.016178694, 0.09655937, -0.095372826, 0.1421154, 0.05931195, 0.1086146, -0.1473184, 0.15178426, 0.04674324, 0.19544281, 0.0996517, -0.13781841, -0.0015831804, 1.0]
# ['yoplait', 'oikos', 'cheese strin', 'cheese', 'cheese string', 'organic cracker', 'triscuit', 'crackers', 'cracker', 'cucumber', 'potatoe', 'ginger', 'garlic', 'garlic clove', 'carrot', 'apple', 'peach', 'annies', 'banana', 'avocado', 'blueberry', 'plum', 'braggs', 'waste management', 'waste management spray', 'spray', 'wm spray', 'odour disposer', 'scicorp', 'odour', 'wm', 'cupcake liner', 'cupcake', 'baking cup', 'organic cookie', 'digestive', 'bage', 'bagel', 'cookie', 'chips', 'chip', 'scrubber', 'sponge', 'garbage bad', 'garbage bag', 'bento', 'organic cheerios']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['eska', 'weston white bread', 'cougreut', 'cheese', 'shredded swiss cheese']
# [-0.010839173, 1.0]
# ['eska', 'parmesan']
# [-0.04126148, 0.09310115, 0.079644546, 0.0628508, 0.21621574, 0.027057461, 0.09291723, 0.016134718, -0.05987265, -0.027750367, -0.11167732, -0.052332763, -0.010839173, 1.0]
# ['eska', 'tomatoes', 'dish soap', 'artichoke in water', 'artichoke', 'pita', 'greek pita', 'melba', 'diet pepsi', 'garbage bags', 'chocolate almonds', 'cheese', 'brie', 'olive oil']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['eau eska', 'fromage mozarella', 'peches', 'jus d’orange']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['bottled water', 'paper cups', 'paper. coffee cups', 'paper. coffee cups in store']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['eau', 'jus', 'jus orange', 'orange']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water bottles', 'chicken', 'cream of chicken', 'palmolive']
# [-0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['water', 'milk', 'cream', 'cereal', 'pasta', 'rice krispies']
# [-0.11397442, -0.05230291, -0.111207075, -0.027761096, -0.059551895, 0.016269222, 0.092917286, 0.027070016, 0.21614805, 0.06285532, 0.079646334, 0.09310166, -0.04125226, -0.03768483, 0.05444585, 0.21875507, -0.010823835, 0.99999994]
# ['water bottles', 'coke', 'triscuit', 'butter', 'hardwood smoked thuringer sausage', 'cracker barrel', 'pringles', 'ed smith pie', 'activia', 'bins', 'jersey milk', 'oh henry', 'ice water', 'med ziploc freezer', 'ziploc freezer', 'tomato paste', 'president choice meduim heavy duty freezer', 'halloween']
# [-0.052346755, -0.010839173, 1.0]
# ['boisson alcoolisée domingo à saveurs variées format économique', 'riz', 'riz dainty']
# [-0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['tums', 'york', 'brookside', 'fishermans friend', 'mints']
# [1.0]
# ['orange crush']
# [0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['iced tea', 'broccoli', 'bananas', 'butter', 'milk', 'ziploc', "orri's", 'mandarins']
# [0.07977276, 0.062845565, 0.21615034, 0.027039941, 0.09301227, 0.016135858, -0.05984097, -0.027639696, -0.11159426, -0.052311253, -0.01088622, 0.99999994]
# ['beer', 'skyr', 'salmon', 'salmon maple', 'oats', 'salsa pc', 'salsa pc organics', 'webber omega', 'stevia', 'cat litter', 'cat food pate', 'organic eggs']
# [0.14217244, 0.054447595, -0.03712118, -0.041152168, 0.09306777, 0.079708286, 0.06292984, 0.0272135, -0.010708461, 0.09288327, 0.01631161, -0.059810944, -0.027792146, -0.111327514, -0.052360035, 0.21869041, 0.21625558, -0.11330566, 0.09977825, 0.059946954, 0.108920604, -0.14716673, 0.15164465, 0.046584245, 0.19540173, -0.13845192, 0.0024911582, -0.09536139, -0.0011236465, -0.13236147, -0.05062824, 0.0648028, 0.08415066, -0.014174385, 1.0]
# ['g2', 'g zero', 'gatorade', 'ham', 'turkey', 'roast beef', 'crossiant', 'zero water', 'eggs', 'strawberry', 'apples', 'cheese', 'cheese slice', 'sausage rounds', 'hotdog buns', 'red pepper', 'banana', 'grapes', 'donuts', 'salad', 'buns', 'dinner rolls', 'carrots', 'yogurt', 'skyr yogurt', 'plain chips', 'chips', 'milk', 'cream', 'coffee', 'keto', 'mozerella', 'pizza cheese', 'saputo', 'cucumber']
# [0.054400526, -0.03770622, -0.040908147, 0.093054116, 0.07960558, 0.0628729, 0.21611355, 0.027098363, 0.09322798, 0.016132005, -0.059853017, -0.027568284, -0.111667946, -0.0523743, -0.010798492, 1.0]
# ['g2', 'bread', 'bagels', 'cream cheese', 'turkey bacon', 'eggs', 'no yolk egg noodles', 'ground chicken', 'fruit', 'yogurt drinks', 'chip dip', 'detergent', 'paper towel', 'lunch mate', 'crackers', 'made good']
# [0.0643779, -0.052346755, -0.111661434, -0.027750367, -0.05984619, 0.016197931, 0.09291723, 0.027058955, 0.21619494, 0.0628508, 0.07963486, 0.09310115, -0.041253414, -0.03769949, 0.054339662, 0.21884768, -0.11398096, -0.014373494, 0.0024360362, 0.08404717, -0.010832924, 1.0]
# ['gatorade', 'perogie', 'skyr', 'strawberrie', 'strawberries', 'glasses', 'eyeglass', 'eye glass', 'vision', 'apples', 'corn flakes', 'milk 1', 'mandarin oranges', 'hot dog bun', 'english muffin', 'no name muffin', 'extra crisp', 'english', "president's choice english", 'risotto', 'doritos', 'ms vickie']
# [-0.052346755, -0.010839173, 1.0]
# ['gatorade', 'potatoes', 'smarties']
# [-0.07290792, -0.014446174, -0.11391242, 0.21888506, 0.05431868, -0.03768794, -0.041233804, 0.093067676, 0.07963454, 0.0628508, 0.21617144, 0.027128711, 0.09291781, 0.016101835, -0.059876293, -0.027719192, -0.111670576, -0.052297793, 0.0024212603, 0.08408297, 0.06439768, -0.14740081, -0.099382274, -0.016293412, 0.017037649, 0.09623282, 0.14176105, 0.05943599, 0.1084637, 0.15158813, -0.050695986, 0.046365805, 0.19548403, 0.09942282, -0.13833946, -0.09518429, -0.0019454656, -0.13270105, -0.01073257, 1.0]
# ['mild sausage', 'hot sausage', 'philly steak', 'philly cheese steak', 'philly', 'sour cream', 'horse radish', 'horseradish pure', 'horseradish, extra hot', 'marinara', 'tomato marinara', 'full red', 'tomato sauce', 'marinara sauce', 'full red mari', 'philly beef', 'salt & pepper', 'salt', 'parsley', '1dedgree', '1 degree', '12 oz soup', '12 oz foam', '10 oz foam', '1st barbeque', '1st wing', '1st degree wing sauce', '1st degree', 'saucemaker', 'extra lean smoked turkey, full round', 'pasta sauce', 'roast beef', 'new york philly', 'medium ground beef tube', '12” tortillis', 'sauce', 'barbecue wing sauce', 'wing sauce', 'shrimp', 'mushrooms']
# [0.21617144, 0.0272738, 0.092917226, 0.01613473, -0.059876285, -0.027750367, -0.111670576, -0.052346755, -0.010839181, 1.0]
# ['pelligrino', 'water', 'chips snack', 'chips snack individual', 'party', 'party favours', 'table cloth party', 'plastic tablecover', 'command hooks', 'plastic table cobmver']
# [-0.010839173, 1.0]
# ['san pellegrino', 'broccoli']
# [1.0]
# ['boison gazeuse']
# [-0.13841963, -0.05231729, -0.11167055, -0.027750367, -0.059895616, 0.01612123, 0.09291723, 0.027064566, 0.21616863, 0.06283733, 0.07962156, 0.09310115, -0.010854311, -0.041270874, 0.054322682, 0.21883953, -0.11398891, -0.01442493, 0.0023999268, 0.08402699, 0.064336516, -0.050813258, -0.13276301, -0.0019304776, -0.09541254, -0.037719578, 1.0]
# ['tzao', 'tazo', 'tazo mint', 'stash mint', 'mint tea', 'chapman cone', 'fruite', 'bread', 'allens', 'allens vinegar', 'clorox', 'cheese string', 'celery', 'brocolli', 'blueberries', 'asian noodle', 'haiku', 'sliced water chestnuts', 'young baby corn in brine', 'carrott', 'cream cheese', 'crunchie 4pk', 'icing sugar', 'gatorade', '1 cup', '1 cup storage', 'ziploc']
# [-0.13841963, -0.05231729, -0.11167055, -0.027750367, -0.059895616, 0.01612123, 0.09291723, 0.027064566, 0.21616863, 0.06283733, 0.07962156, 0.09310115, -0.010854311, -0.041270874, 0.054322682, 0.21883953, -0.11398891, -0.01442493, 0.0023999268, 0.08402699, 0.064336516, -0.050813258, -0.13276301, -0.0019304776, -0.09541254, -0.037719578, 1.0]
# ['crush', 'root beer', 'cola', 'chipa', 'cookies', 'chocolate milk', 'milk', 'butter', 'canned fruit', 'frozen veges', 'zucchini', 'bacon', 'pc spice blends', 'pepper', 'black pepper', 'speedstick', 'olay cleansing', 'goldfish', 'goldfish cheddar and sour cream', 'gap carrd', 'gap card', 'gap', 'cheese', 'cheese strings', 'mozza cheese', 'pepsi', 'unsalted butter']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['soda', 'gingerale', 'ice', 'pepsi']
# [0.027057461, 0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['pelligrino', 'grapes', 'dates', 'ground beef', 'ground pork', 'pork', 't&t', 'buns', 'ground beef and pork']
# [0.21617144, 0.0272738, 0.092917226, 0.01613473, -0.059876285, -0.027750367, -0.111670576, -0.052346755, -0.010839181, 1.0]
# ['san pellegrino', 'pudding', 'budding ham', 'sliced ham', 'crispy baked products', 'crispy', 'prime fresh poultry products', 'prime', 'bulk foods', 'neocitran']
# [1.0]
# ['v8 cocktail']
# [-0.010839173, 1.0]
# ['v8', 'cereal']
# [0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['tofu', 'classik dishwasher sanitizer', 'deli plastic container, clear 32oz', 'chopsticks', 'soy sauce', 'lysol', 'bleach']
# [0.0643779, -0.052346755, -0.111661434, -0.027750367, -0.05984619, 0.016197931, 0.09291723, 0.027058955, 0.21619494, 0.0628508, 0.07963486, 0.09310115, -0.041253414, -0.03769949, 0.054339662, 0.21884768, -0.11398096, -0.014373494, 0.0024360362, 0.08404717, -0.010832924, 1.0]
# ['mountain dew', 'apple juice', 'g2', 'pizza', 'pizza pockets', 'frozen dinners', 'mac and cheese', 'michelena', 'tomato soup', 'ketchup', 'bacon', 'bread', 'popsicles', 'icepop', 'chips', 'gravy & sauce mixes', 'swiss chalet', 'frozen fruit', 'lucky charms', 'cookies', 'juice boxes', 'gatorade powder']
# [-0.049819738, -0.13818453, -0.09540739, -0.0017576502, -0.13273114, -0.050866242, 0.0645397, 0.08424342, 0.0024288078, -0.0142600285, -0.11381281, 0.21903962, 0.05431655, -0.03764891, -0.041261476, 0.09329042, 0.079712555, 0.06288465, 0.21632208, 0.027176863, 0.09329144, 0.016346492, -0.05973623, -0.027406858, -0.11161989, -0.052161492, 0.09937401, 0.19543174, 0.04636586, 0.16919582, 0.08635366, 0.17228295, 0.123591095, -0.050403606, 0.113750115, 0.038277734, 0.050473414, -0.09000045, -0.06843252, -0.1309026, 0.07682803, -0.016592873, 0.15163054, -0.00089426036, -0.034222156, -0.072373115, -0.099308535, -0.015870823, 0.017254926, 0.09636013, 0.14191939, 0.059500203, 0.108884625, -0.1473854, -0.010869032, 0.99999994]
# ['odouls', 'take out cutlery', 'cutlery', 't shirt bags', 'small ziplock', 'plastic bags', 'dawn', 'ground beef', 'greek', 'tartar', 'chipotle dressing', 'chipotle', 'forty creek bbq', 'white vinegar', 'malt vinegar', 'apple cider vinegar', 'vinegar', 'ranch', 'bbq', 'franks', 'worchestershire sauce', 'worchestershire', 'brown sugar', 'lemon juice', 'coconut milk', 'corn', 'corn frozen', 'frozen peas', 'frozen corn', 'ice cream', 'cheesecake', 'german chocolate cake', 'spring rolls', 'chicken fingers', 'chicken fillets', 'sweet potato fries', 'fries', 'whipping cream', 'sour crema', 'sour cream', 'creamers', 'milk', 'cheddar cheese', 'romaine', 'green onions', 'red peppers', 'green peppers', 'large tomatoes', 'tomatoes', '12 inch tortillas', 'tortillas', 'spinach', 'limes', 'leaf lettuce', 'mushrooms', 'cauliflowers']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['biere', 'jus tomate', 'dattes', 'pizza pochette']
# [-0.052346755, -0.010839173, 1.0]
# ['naya', 'sauce st hurect', 'frites']
# [-0.111670576, -0.052346755, -0.010839173, 1.0]
# ['eau', 'fraises entières', 'fraises', 'orange']
# [1.0]
# ['san pellegrino']
# [0.0628508, 0.2161742, 0.027057461, 0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839172, 1.0]
# ['dairymilk', 'dairy milk cadbury', 'excel', 'kraft', 'battery', 'tidy', 'laundry detergent', 'laundry', 'pepsi diet', 'pepsi', 'red bull yellow']
# [0.09615226, 0.2189724, 0.05463264, -0.037551884, -0.041055147, 0.09318464, 0.07975213, 0.06283731, 0.21616936, 0.026937563, 0.09304516, 0.016156537, -0.05986567, -0.027561095, -0.11172456, -0.05239581, -0.11395695, -0.014078164, 0.0024001938, 0.19558436, 0.14181691, 0.059358105, 0.10847554, -0.14745164, 0.15171607, 0.046283185, 0.099452324, 0.08397186, -0.13809538, -0.095436834, -0.0019929397, -0.13212888, -0.050637946, 0.064398944, -0.010566773, 1.0]
# ['mars', 'skittles', 'stride', 'fisherman', 'triple push pop', 'push pop', 'surprise', 'bottle pop', 'baby bottle', 'ritz', 'cracker', 'luch on', 'oreo', 'oriville', 'bits cheese cracker sandwiches', 'bits & bites', 'paper towel', 'power steering', 'oil', '10w30', 'peach', 'cut wax', 'vinegar', 'ziplock', 'allens', 'tetley', 'tea', 'betty crocker', 'sundae', 'twin sugar', 'clamato', 'cream', 'table cream', 'auto', 'engine', 'candy']
# [0.084045656, -0.052344862, -0.11166299, -0.027744237, -0.05982618, 0.016208807, 0.09292351, 0.02704238, 0.21618979, -0.0108396895, 0.06285211, 0.09310338, -0.0412475, -0.037685502, 0.054319717, 0.2188576, -0.11397762, -0.0143875675, 0.0024422402, 0.07963361, 1.0]
# ['red bull', 'toilet paper', 'eggs', 'meat', 'cereal, granola & bars', 'trail mix', 'flower', 'frozen pizza', 'red rain', 'candy', 'gum', 'pasta', 'wheels', 'diced tomatoes', 'cheese', 'italian seasoning', 'pepperoni', 'bread', 'chill', 'baking', 'cakes & desserts']
# [1.0]
# ['skittles']
# [0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['san benedetto', 'perrier', 'evian', 'bocconcini', 'wheat thins', 'crackers', 'cheese crackers']
# [0.07977276, 0.062845565, 0.21615034, 0.027039941, 0.09301227, 0.016135858, -0.05984097, -0.027639696, -0.11159426, -0.052311253, -0.01088622, 0.99999994]
# ['san benedetto', 'ripple unsweetened', 'lunch bag', 'frozen pizza', 'arugula', 'hello bello wipes', 'hello bello size 5', 'water wipes', 'hello bello wasb', 'fruit', 'berry jam', 'pudding']
# [0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['sprite', 'spriz up', 'cat litter', 'chicken wings', 'sweet chili chicken wings', 'oragel', 'cabbage', 'saurkraut']
# [-0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839173, 1.0]
# ['zero sprite', 'waffles & pancakes', 'eggo', '7up', 'drumstick', 'nestea zero']
# [0.0628508, 0.2161742, 0.027057461, 0.09291723, 0.016134718, -0.059876293, -0.027750367, -0.111670576, -0.052346755, -0.010839172, 1.0]
# ...
# [1.0]
# ['the little kernel']
# [1.0]
# ['cabbage rolls']
# [1.0]
# ['squishmallows']
# [1.0]
# ['cat litter']
# [1.0]
# ['artichoke']
# [1.0]
# ['melatonin gummies']
# [1.0]
# ['kitchen sponge cellulose']
# [1.0]
# ['eggs']
# [1.0]
# ['cheetos']
# [1.0]
# ['gatorade']
# [1.0]
# ['yves']
# [1.0]
# ['chef coat']
# [1.0]
# ['biscuit']
# [1.0]
# ['tofu']
# [1.0]
# ['tilapia fillets']
# [1.0]
# ['moong']
# [1.0]
# ['chicken']
# [1.0]
# ['slow cooker']
# [1.0]
# ['mini focaccia']
# [1.0]
# ['dining table']
# [1.0]
# ['viande']
# [1.0]
# ['cheesecake']
# [1.0]
# ['illy coffee']
# [1.0]
# ['mulino bianco']
# [1.0]
# ['oatmeal crisp']
# [1.0]
# ['ensure']
# [1.0]
# ['can opener']
# [1.0]
# ['spaghetti squash']
# [1.0]
# ['lamb']
# [1.0]
# ['beef burgers']
# [1.0]
# ['pork chops']
# [1.0]
# ['tapioca']
# [1.0]
# ['bacon']
# [1.0]
# ['cape']
# [1.0]
# ['ice tea']
# [1.0]
# ['tortilla']
# [1.0]
# ['nakin']
# [1.0]
# ['organic granola']
# [1.0]
# ['enchilada sauce']
# [1.0]
# ['paper bags']
# [1.0]
# ['baskets']
# [1.0]
# ['ensure']
# [1.0]
# ['qukr cereales erable cdn 475g']
# [1.0]
# ['indian food']
# [1.0]
# ['lettuce & leafy vegetables']
# [1.0]
# ['atlantic salmon']
# [1.0]
# ['food coloring']
# [1.0]
# ['gatorade']
# [1.0]
# ['live clean']
# [1.0]
# ['body scrub']
# [1.0]
# ['m&m']
# [1.0]
# ['pregnancy test']
# [1.0]
# ['crispy chicken']
# [1.0]
# ['can of corn']
# [1.0]
# ['butter']
# [1.0]
# ['huggies']
# [1.0]
# ['fiber optic christmas tree']
# [1.0]
# ['plastic wrap']
# [1.0]
# ['assaisonnement viande']
# [1.0]
# ['halloween candy']
# [1.0]
# ['lemons']
# [1.0]
# ['birthday cake']
# [1.0]
# ['cupcake']
# [1.0]
# ['chocolate']
# [1.0]
# ['gay lea spreadables']
# [1.0]
# ['beef rib']
# [1.0]
# ['cake']
# [1.0]
# ['tournedoes']
# [1.0]
# ['downy']
# [1.0]
# ['pumpkin']
# [1.0]
# ['skittles']
# [1.0]
# ['life at home taper mug']
# [1.0]
# ['milk']
# [1.0]
# ['pizza pocket']
# [1.0]
# ['grill mat']
# [1.0]
# ['cheese shredded']
# [1.0]
# ['vh stir fry sauce']
# [1.0]
# ['oral b']
# [1.0]
# ['pc chips']
# [1.0]
# ['kids toothpaste']
# [1.0]
# ['cholupa']
# [1.0]
# ['bookcase']
# [1.0]
# ['sugar']
# [1.0]
# ['raw pet food']
# [1.0]
# ['distilled water']
# [1.0]
# ['coconut water']
# [1.0]
# ['gatorade']
# [1.0]
# ['cottonelle flushable wipes']
# [1.0]
# ['shea moisture shampoo and conditioner']
# [1.0]
# ['jars']
# [1.0]
# ['lemons']
# [1.0]
# ['turkey']
# [1.0]
# ['hot dogs']
# [1.0]
# ['toddler']
# [1.0]
# ['all natural peanut butter']
# [1.0]
# ['cake']
# [1.0]
# ['chocolate chip cookies']
# [1.0]
# ['curel']
# [1.0]
# ['green peppers']
# [1.0]
# ['mozzarella cheese']
# [1.0]
# ['canned salmon']
# [1.0]
# ['ground beef']
# [1.0]
# ['dress']
# [1.0]
# ['crema']
# [1.0]
# ['lasagne noodles']
# [1.0]
# ['milk chocolate bar']
# [1.0]
# ['purex']
# [1.0]
# ['becel']
# [1.0]
# ['macaroni au fromage']
# [1.0]
# ['starbuck']
# [1.0]
# ['bistro']
# [1.0]
# ['ice cream dixie cups']
# [1.0]
# ['weiners']
# [1.0]
# ['cetaphil']
# [1.0]
# ['barilla']
# [1.0]
# ['gizella']
# [1.0]
# ['tassimo']
# [1.0]
# ['lee kum kee']
# [1.0]
# ['kids toothpaste']
# [1.0]
# ['pc organics spread']
# [1.0]
# ['speed sew']
# [1.0]
# ['blue plums']
# [1.0]
# ['margarine']
# [1.0]
# ['frozen cauliflower']
# [1.0]
# ['udon']
# [1.0]
# ['mad mexican']
# [1.0]
# ['ferraro rocher']
# [1.0]
# ['swiffer']
# [1.0]
# ['sushi']
# [1.0]
# ['nescafe']
# [1.0]
# ['lettuce']
# [1.0]
# ['outdoor furniture']
# [1.0]
# ['fish']
# [1.0]
# ['ham']
# [1.0]
# ['prunes']
# [1.0]
# ['beef tenderloin']
# [1.0]
# ['caffe']
# [1.0]
# ['watermelon']
# [1.0]
# ['seafood sauce']
# [1.0]
# ['no name spices']
# [1.0]
# ['orange juice']
# [1.0]
# ['suger']
# [1.0]
# ['chocolate spread']
# [1.0]
# ['bathroom tissue']
# [1.0]
# ['caltrate plus']
# [1.0]
# ['inserts & insoles']
# [1.0]
# ['gnocchi']
# [1.0]
# ['celery']
# [1.0]
# ['slamscuits']
# [1.0]
# ['cheese']
# [1.0]
# ['cookware']
# [1.0]
# ['biore']
# [1.0]
# ['laxatives']
# [1.0]
# ['la rocca cakes']
# [1.0]
# ['downy']
# [1.0]
# ['tart shells']
# [1.0]
# ['snow peas']
# [1.0]
# ['acerola']
# [1.0]
# ['ear plugs']
# [1.0]
# ['ham']
# [1.0]
# ['enjoy life']
# [1.0]
# ['romaine lettuce']
# [1.0]
# ['halloween']
# [1.0]
# ['dessert']
# [1.0]
# ['corn']
# [1.0]
# ['nongshim']
# [1.0]
# ['natural turbinado sugar']
# [1.0]
# ['grape jelly']
# [1.0]
# ['heinz ketchup']
# [1.0]
# ['coffee cream']
# [1.0]
# ['croutons']
# [1.0]
# ['nut pod']
# [1.0]
# ['pc plant based']
# [1.0]
# ['smart ones']
# [1.0]
# ['quaker gluten free']
# [1.0]
# ['frozen dessert']
# [1.0]
# ['floor pillow']
# [1.0]
# ['lysol wipes']
# [1.0]
# ['rimmel london']
# [1.0]
# ['canned muchrooms']
# [1.0]
# ['milk']
# [1.0]
# ['mango pulp']
# [1.0]
# ['vegetable oil']
# [1.0]
# ['family size caeser salad']
# [1.0]
# ['thermal paper']
# [1.0]
# ['cereal']
# [1.0]
# ['chapmans yogurt']
# [1.0]
# ['salmon']
# [1.0]
# ['benadryl']
# [1.0]
# ['mushroom gravy']
# [1.0]
# ['cotton gloves']
# [1.0]
# ['candy']
# [1.0]
# ['bain']
# [1.0]
# ['boys rain boots']
# [1.0]
# ['align']
# [1.0]
# ['goldfish crackers']
# [1.0]
# ['fruits & vegetables']
# [1.0]
# ['smart sweets']
# [1.0]
# ['poppables']
# [1.0]
# ['s video cable']
# [1.0]
# ['ross']
# [1.0]
# ['deli meat']
# [1.0]
# ['jamieson']
# [1.0]
# ['keto']
# [1.0]
# ['chipits']
# [1.0]
# ['printer']
# [1.0]
# ['egg white']
# [1.0]
# ['nesco']
# [1.0]
# ['hummus et tartinades']
# [1.0]
# ['gluten free stuffing']
# [1.0]
# ['watermelon']
# [1.0]
# ['serving dish']
# [1.0]
# ['mixed berries']
# [1.0]
# ['quinoa']
# [1.0]
# ['candy']
# [1.0]
# ['frozen foods']
# [1.0]
# ['cantu']
# [1.0]
# ['mussel']
# [1.0]
# ['enfamil']
# [1.0]
# ['club house allspice']
# [1.0]
# ['sugar']
# [1.0]
# ['white kidney bean extract']
# [1.0]
# ['tide']
# [1.0]
# ['peppers']
# [1.0]
# ['paneer']
# [1.0]
# ['spring roll wrappers']
# [1.0]
# ['boneless rib end pork chops, club pack']
# [1.0]
# ['san']
# [1.0]
# ['ricotta cheese']
# [1.0]
# ['lunch box']
# [1.0]
# ['coffee pods']
# [1.0]
# ['tea']
# [1.0]
# ['harvest snaps']
# [1.0]
# ['jamieson soft chews calcium']
# [1.0]
# ['eau']
# [1.0]
# ['pantene']
# [1.0]
# ['newtons']
# [1.0]
# ['potatoes']
# [1.0]
# ['green weighted']
# [1.0]
# ['pasta']
# [1.0]
# ['disposable cups']
# [1.0]
# ['halloumi cheese']
# [1.0]
# ['avocat']
# [1.0]
# ['coke zero']
# [1.0]
# ['jolly jumper']
# [1.0]
# ['greenfield natural meat co.']
# [1.0]
# ['triscuit']
# [1.0]
# ['juice boxes']
# [1.0]
# ['goldfish']
# [1.0]
# ['diced tomatoes no salt']
# [1.0]
# ['bread']
# [1.0]
# ['westlab']
# [1.0]
# ['marine collagen']
# [1.0]
# ['pencil crayons']
# [1.0]
# ['bobo']
# [1.0]
# ['kraft']
# [1.0]
# ['deoderant']
# [1.0]
# ['hemp hearts']
# [1.0]
# ['bananas']
# [1.0]
# ['plum']
# [1.0]
# ['schweppes']
# [1.0]
# ['nature clean soap']
# [1.0]
# ['field roast']
# [1.0]
# ['sugar']
# [1.0]
# ['pampers wipes']
# [1.0]
# ['cranberry juice']
# [1.0]
# ['dryer sheets']
# [1.0]
# ['jamieson']
# [1.0]
# ['yogurt']
# [1.0]
# ['coverlet']
# [1.0]
# ['concentrated real lemons']
# [1.0]
# ['pc chocolate syrup']
# [1.0]
# ['enfagrow']
# [1.0]
# ['no name']
# [1.0]
# ['fibre']
# [1.0]
# ['bamboo']
# [1.0]
# ['pharmacy fax number']
# [1.0]
# ['pepsi']
# [1.0]
# ['rainbow trout']
# [1.0]
# ['peach, plum & nectarines']
# [1.0]
# ['mozarella saputo']
# [1.0]
# ['lesser evil']
# [1.0]
# ['strawberry']
# [1.0]
# ['pc enamelled cast iron cookware']
# [1.0]
# ['bernardin']
# [1.0]
# ['bran bread']
# [1.0]
# ['mat']
# [1.0]
# ['joe fresh']
# [1.0]
# ['beef jerky']
# [1.0]
# ['diapers']
# [1.0]
# ['bentgo']
# [1.0]
# ['canned peas']
# [1.0]
# ['tomatoes']
# [1.0]
# ['chicken']
# [1.0]
# ['biscuits']
# [1.0]
# ['celery seeds']
# [1.0]
# ['fancy feast']
# [1.0]
# ['sugar']
# [1.0]
# ['tylenol']
# [1.0]
# ['coffee']
# [1.0]
# ['chicken breast']
# [1.0]
# ['rviita']
# [1.0]
# ['betty light']
# [1.0]
# ['angus beef']
# [1.0]
# ['gift card']
# [1.0]
# ['gold peak']
# [1.0]
# ['apples']
# [1.0]
# ['dove body wash']
# [1.0]
# ['blueberries']
# [1.0]
# ['ecover']
# [1.0]
# ['gluten free pizza crust']
# [1.0]
# ['no name oil']
# [1.0]
# ['dates']
# [1.0]
# ['frozen chicken']
# [1.0]
# ['organic eggs']
# [1.0]
# ['dried milk']
# [1.0]
# ['finish']
# [1.0]
# ['seive']
# [1.0]
# ['ketchup']
# [1.0]
# ['milk 2 go']
# [1.0]
# ['ground beef']
# [1.0]
# ['laundry basket']
# [1.0]
# ['grape tomatoes']
# [1.0]
# ['pizza']
# [1.0]
# ['coffee mate bliss oat plain non dairy liquid coffee enhancer']
# [1.0]
# ['pears']
# [1.0]
# ['boom chika']
# [1.0]
# ['fitbit']
# [1.0]
# ['salmon']
# [1.0]
# ['straw tumbler']
# [1.0]
# ['vegemite']
# [1.0]
# ['boon']
# [1.0]
# ['fall decor']
# [1.0]
# ["campbell's cream of mushroom soup"]
# [1.0]
# ['dental floss']
# [1.0]
# ['fody salad dressing']
# [1.0]
# ['pineapple cake']
# [1.0]
# ['tylenol']
# [1.0]
# ['spam']
# [1.0]
# ['candle']
# [1.0]
# ['cannedsalmon']
# [1.0]
# ['tostitos']
# [1.0]
# ['litter']
# [1.0]
# ['tortillas de maïs']
# [1.0]
# ['bacon']
# [1.0]
# ['potatoes']
# [1.0]
# ['orange']
# [1.0]
# ['canned peaches']
# [1.0]
# ['pâtes']
# [1.0]
# ['beyond meat']
# [1.0]
# ['crave']
# [1.0]
# ['turkey bacon']
# [1.0]
# ['tonica']
# [1.0]
# ['whole wheat pasta']
# [1.0]
# ['organic raisins']
# [1.0]
# ['canned pasta']
# [1.0]
# ['bento box']
# [1.0]
# ['oreos']
# [1.0]
# ['snow boots girls']
# [1.0]
# ['tassimo chai']
# [1.0]
# ['vanilla extract']
# [1.0]
# ['proferrin']
# [1.0]
# ['ocean spray']
# [1.0]
# ['frozen burrito']
# [1.0]
# ['pull ups']
# [1.0]
# ['compote aux pommes']
# [1.0]
# ['astro plain yogurt 0%']
# [1.0]
# ['cornstarch']
# [1.0]
# ['piment']
# [1.0]
# ['hot wheels 20 cars']
# [1.0]
# ['cotton swabs']
# [1.0]
# ['baked chips']
# [1.0]
# ['mascarpone']
# [1.0]
# ['tomato paste']
# [1.0]
# ['cheese blocks']
# [1.0]
# ['apples']
# [1.0]
# ['fromage balderson']
# [1.0]
# ['rice']
# [1.0]
# ['woolite 16 oz']
# [1.0]
# ['mussel']
# [1.0]
# ['shitake']
# [1.0]
# ['scrub pads']
# [1.0]
# ['chicken']
# [1.0]
# ['maple sugar']
# [1.0]
# ['wagh bakri tea']
# [1.0]
# ['cereal']
# [1.0]
# ['ackee']
# [1.0]
# ['granulated sugar']
# [1.0]
# ['ziploc']
# [1.0]
# ['pina colada']
# [1.0]
# ['food color']
# [1.0]
# ['kettlebells']
# [1.0]
# ['becel']
# [1.0]
# ['500ml jars']
# [1.0]
# ['laffy taffy']
# [1.0]
# ['deals']
# [1.0]
# ['vim cream']
# [1.0]
# ['coconut cookies']
# [1.0]
# ['monster energy']
# [1.0]
# ['oreo']
# [1.0]
# ['peppers']
# [1.0]
# ['tumbler']
# [1.0]
# ['oikos']
# [1.0]
# ['beurre amande noisette']
# [1.0]
# ['onion']
# [1.0]
# ['pb and me']
# [1.0]
# ['baby monitor']
# [1.0]
# ['uncrustables']
# [1.0]
# ['once upon a farm']
# [1.0]
# ['feminine hygiene']
# [1.0]
# ['coleslaw']
# [1.0]
# ['pepperoni']
# [1.0]
# ['price match']
# [1.0]
# ['washable markers']
# [1.0]
# ['ice cream sandwich']
# [1.0]
# ['naan']
# [1.0]
# ['oreo']
# [1.0]
# ['low sodium club soda']
# [1.0]
# ['pampers']
# [1.0]
# ['cake mix']
# [1.0]
# ['sistema container']
# [1.0]
# ['flannel twin sheet']
# [1.0]
# ['bic lighter']
# [1.0]
# ['frutti']
# [1.0]
# ['hello toothpaste']
# [1.0]
# ['braun age precision digital thermometer']
# [1.0]
# ['yogurt']
# [1.0]
# ['teeth whitening']
# [1.0]
# ['cake decorating']
# [1.0]
# ['manicotti']
# [1.0]
# ['curry paste']
# [1.0]
# ['jars']
# [1.0]
# ['tide free powder']
# [1.0]
# ['salmon']
# [1.0]
# ['apple air pods']
# [1.0]
# ['cassonade']
# [1.0]
# ['dishwasher tab']
# [1.0]
# ['pork back ribs']
# [1.0]
# ['shirataki noodles']
# [1.0]
# ['ribena']
# [1.0]
# ['paneer']
# [1.0]
# ['cake']
# [1.0]
# ['turmeric force']
# [1.0]
# ['granola bars']
# [1.0]
# ['candles']
# [1.0]
# ['halibut']
# [1.0]
# ['pizza pops']
# [1.0]
# ['nature clean soap']
# [1.0]
# ['dessert stands']
# [1.0]
# ['bologna']
# [1.0]
# ['wine']
# [1.0]
# ['miso']
# [1.0]
# ['neutrogena body']
# [1.0]
# ['bacon']
# [1.0]
# ['lava']
# [1.0]
# ['butter']
# [1.0]
# ['jamieson blueberry']
# [1.0]
# ['vanilla cupcakes']
# [1.0]
# ['shower curtains']
# [1.0]
# ['stewing beef']
# [1.0]
# ['sour cream glaze']
# [1.0]
# ['cauliflower rice']
# [1.0]
# ['chocolate chips']
# [1.0]
# ['frozen peaches']
# [1.0]
# ['pizza']
# [1.0]
# ['sparkling water']
# [1.0]
# ['depends']
# [1.0]
# ['cheese']
# [1.0]
# ['voltaren emulgel']
# [1.0]
# ['confitures et tartinades sucrées']
# [1.0]
# ['numi']
# [1.0]
# ['pampers size 5']
# [1.0]
# ['walnuts']
# [1.0]
# ['masks']
# [1.0]
# ['special k']
# [1.0]
# ['maille vinaigrette']
# [1.0]
# ['canned tuna']
# [1.0]
# ['international delight']
# [1.0]
# ['apple']
# [1.0]
# ['chicken drumsticks']
# [1.0]
# ['cookies']
# [1.0]
# ['hot sauce']
# [1.0]
# ['can opener']
# [1.0]
# ['potatoes']
# [1.0]
# ['baskets']
# [1.0]
# ['lays chips']
# [1.0]
# ['pumpkin']
# [1.0]
# ["kellogg's cereal"]
# [1.0]
# ['sardine']
# [1.0]
# ['soppressata thin sliced']
# [1.0]
# ['chicken legs back attached']
# [1.0]
# ['dark chocolate']
# [1.0]
# ['vegan butter']
# [1.0]
# ['mug']
# [1.0]
# ['egg']
# [1.0]
# ['ramen noddle']
# [1.0]
# ['hot pepper']
# [1.0]
# ['household cleaners']
# [1.0]
# ['chicken']
# [1.0]
# ['rib eye']
# [1.0]
# ['dove deodorant']
# [1.0]
# ['coffee maker']
# [1.0]
# ['parchment muffin cups']
# [1.0]
# ['v8 cocktail']
# [1.0]
# ['parathas']
# [1.0]
# ['unsalted butter']
# [1.0]
# ['hardbite']
# [1.0]
# ['maggi sauce']
# [1.0]
# ['stevia']
# [1.0]
# ['oranges']
# [1.0]
# ['laxaday']
# [1.0]
# ['utensil holder']
# [1.0]
# ['hair spray']
# [1.0]
# ['prime rib roast']
# [1.0]
# ['water']
# [1.0]
# ['halloween candy']
# [1.0]
# ['nicoderm']
# [1.0]
# ['hangar']
# [1.0]
# ['canned tuna']
# [1.0]
# ['huile coco']
# [1.0]
# ['mozzarella']
# [1.0]
# ['tikka']
# [1.0]
# ['m&ms']
# [1.0]
# ['table consol']
# [1.0]
# ['vitimin d']
# [1.0]
# ['sidekicks']
# [1.0]
# ['facial tissue']
# [1.0]
# ['peach, plum & nectarines']
# [1.0]
# ['dulcolax']
# [1.0]
# ['cereal']
# [1.0]
# ['corn squares']
# [1.0]
# ['crispy oninos']
# [1.0]
# ['marbled cheese']
# [1.0]
# ['salmon']
# [1.0]
# ['honey bunches of oats almond with 25% more almonds cereal']
# [1.0]
# ['salsa']
# [1.0]
# ['beets']
# [1.0]
# ['broad beans']
# [1.0]
# ['gluten free pizza']
# [1.0]
# ['all bran']
# [1.0]
# ['ham slices']
# [1.0]
# ['kraft parmesan cheese']
# [1.0]
# ['tortillas']
# [1.0]
# ['bras']
# [1.0]
# ['macaroni']
# [1.0]
# ['floor pillow']
# [1.0]
# ['advent']
# [1.0]
# ['organic face wash']
# [1.0]
# ['ensure']
# [1.0]
# ['nutrasea']
# [1.0]
# ['floor cushion']
# [1.0]
# ['andalou']
# [1.0]
# ['larsen wieners']
# [1.0]
# ['haddock']
# [1.0]
# ['gound beef']
# [1.0]
# ['duration gel']
# [1.0]
# ['pull ups']
# [1.0]
# ['gaterade zero']
# [1.0]
# ['dawn dish']
# [1.0]
# ['water 4l']
# [1.0]
# ['couscous']
# [1.0]
# ['dishwasher tabs']
# [1.0]
# ['bolognese']
# [1.0]
# ['greek yogurt']
# [1.0]
# ['phstmacy phone number']
# [1.0]
# ['sweet potato']
# [1.0]
# ['japanese green tea']
# [1.0]
# ['eggs']
# [1.0]
# ['kitchens of india']
# [1.0]
# ['masks']
# [1.0]
# ['bao']
# [1.0]
# ['oxi']
# [1.0]
# ['special k']
# [1.0]
# ['labneh']
# [1.0]
# ['pasta shells']
# [1.0]
# ['pc blue menu bread']
# [1.0]
# ['charmin']
# [1.0]
# ['vanilla ice cream']
# [1.0]
# ['butterball turkey']
# [1.0]
# ['bladerson cheese']
# [1.0]
# ['chocolate wafers']
# [1.0]
# ['chapmans ice cream sundae']
# [1.0]
# ['salad']
# [1.0]
# ['thai kitchen']
# [1.0]
# ['spinach pasta']
# [1.0]
# ['sturgeon falls']
# [1.0]
# ['finesse']
# [1.0]
# ['seventh generation']
# [1.0]
# ['shrimp']
# [1.0]
# ['canada hats']
# [1.0]
# ['apples']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6eeb7dd695e6> in <module>
#       3 for i in range(len(json_df)):
#       4     vocab = json_df.values[i][0]  # creating vocab
# ----> 5     model = Word2Vec([vocab], min_count = 1)  # training model
#       6     score, sim, odd= [],[],[]
#       7     k = len(vocab)
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in __init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     428                 corpus_iterable=corpus_iterable, corpus_file=corpus_file, total_examples=self.corpus_count,
#     429                 total_words=self.corpus_total_words, epochs=self.epochs, start_alpha=self.alpha,
# --> 430                 end_alpha=self.min_alpha, compute_loss=self.compute_loss, callbacks=callbacks)
#     431         else:
#     432             if trim_rule is not None:
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1071                     corpus_iterable, cur_epoch=cur_epoch, total_examples=total_examples,
#    1072                     total_words=total_words, queue_factor=queue_factor, report_delay=report_delay,
# -> 1073                     callbacks=callbacks, **kwargs)
#    1074             else:
#    1075                 trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch_corpusfile(
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in _train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay, callbacks)
#    1427         for thread in workers:
#    1428             thread.daemon = True  # make interrupting the process with ctrl+c easier
# -> 1429             thread.start()
#    1430
#    1431         trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#
# ~\Anaconda3\lib\threading.py in start(self)
#     855                 del _limbo[self]
#     856             raise
# --> 857         self._started.wait()
#     858
#     859     def run(self):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
# 4. Consecutive queries compared and similarity score produced for *** all Sessions in dataset ***
from gensim.models import Word2Vec
for i in range(len(json_df)):
    vocab = json_df.values[i][0]    # creating vocab
    model = Word2Vec([vocab], min_count = 1)   # training model
    score, sim = [],[]
    k = len(vocab)
    for j in range(k-1):
        ls = model.wv.similarity(vocab[j],vocab[j+1])  # analyzing model
        score.append(ls)
    print(score)
    print(vocab)
# Out:
# []
# ['water bottle']
# [-0.013514948, -0.023671674, -0.010839173]
# ['eau de source', 'nutella', 'huile d’olive', 'chou fleur']
# [0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['coffee crisp', 'coffee', 'kinder', 'beuno', 'salad', 'bacon']
# [0.0038111245, -0.0009846962, 0.0003889287, 0.11937966, -0.14902948, 0.06548712, -0.09824341, 0.027215723, -0.0755177, -0.030191496, 0.10945788, 0.014984888, 0.044884916, -0.14444871, 0.0053134076, 0.01925817, 0.13885167, -0.044224247, -0.013236468, -0.0074412865, 0.067342535, 0.107436225, 0.029060697, -0.09362363, -0.05141988, 0.110187575, 0.002829252, 0.00734705, -0.23736587, 0.025477832, -0.032352634, 0.050734136, 0.0011917986, 0.063331686, -0.14725435, -0.102968745, -0.008044168, -0.05984464, 0.064070195, -0.06714499, 0.11907527, -0.06721938, -0.010680665]
# ['water', 'canned drinks', 'soda', 'hot dog buns', 'hot dogs', 'milk', 'yogurt', 'cheddar cheese', 'nacho cheese', 'mozzarella', 'margarine', 'cucumbers', 'broccoli, cabbage & cauliflower', 'potatoes', 'celery', 'onions', 'garlic', 'canned tomatoes', 'apples', 'oranged', 'oranges', 'bananas', 'pears', 'apple sauce', 'juice', 'corn starch', 'rice', 'sugar', 'cream of tartar', 'instant yeast', 'yeast', 'ground beef', 'honey ham', 'chicken tenders', 'chicken broth', 'gold fish', 'pretzles', 'veggie straws', 'paper bowls', 'spoons', 'bleach', 'fabric softner', 'soap', 'soap refills']
# [-0.010839173]
# ['eau', 'jus de canneberge']
# [-0.030296177, 0.10960891, 0.014882498, 0.044643596, -0.14455914, 0.0048425104, 0.019152312, 0.13927871, -0.044562627, -0.013485333, -0.02367525, -0.010830897]
# ['case of water', 'grapefruit', 'grapefruit juice', 'chips', 'loads of japalano', 'loads of chips', 'milk', 'whipped cream', 'sauages', 'vienna sauages', 'too dogs', 'top dogs', 'lemon']
# [-0.023671674, -0.010839173]
# ['water', 'butter', 'fruit packs']
# [0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'tide', 'garbage bags', 'pantene', 'polident', 'polident 3 minute', 'bacon']
# [-0.11228521, -0.013413804, -0.04451552, 0.13888626, 0.01915339, 0.0049065417, -0.14419645, 0.044668727, 0.015017101, 0.10942225, -0.030302342, -0.07639712, 0.027242068, -0.09804512, 0.0654425, -0.14894004, 0.11942791, 0.00068645173, -0.00071364176, -0.07598815, 0.06736544, 0.1076512, 0.07362502, 0.0029250244, 0.11889114, -0.06747569, 0.063351184, -0.060012516, -0.008024028, -0.018558184, -0.010839173]
# ['water', 'orange juice', 'apple juice', 'pepperoni', 'salami', 'weiner', 'hot dog', 'eggs', 'dairy & eggs', 'hashbrowns', 'lettuce', 'ginger', 'bread', 'buns', 'chips', 'chip dip', 'waffles', 'cheese slices', 'cookies', 'kraft dinner', 'tea', 'chocloate syrup', 'milk', 'oreo sandwich', 'popsicle', 'fuzzy peach popsicle', 'rice', 'salt fish', 'ackee', 'geen onion', 'garlic', 'tums']
# [0.109524556, 0.015015273, 0.044671305, -0.14454001, 0.004852889, 0.019152299, 0.13887985, -0.044132903, -0.013432669, -0.02365179, -0.01088622]
# ['water', 'epsom salts', 'garlic', 'cotton balls', 'cotton puffs', 'jumbo puffs', 'granola bars', 'simply orange', 'absorbent puffs', 'absorbent', 'face cleaner wipes', 'face cleaner']
# [0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'coffee', 'coffee mate', 'tide pods', 'downy', 'fabric conditioner', 'polident', 'hair colour']
# [0.044735733, -0.1445247, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839181]
# ['water', 'juice', 'bread', 'hashbrown', 'fruit cups', 'vitamin c', 'apples', 'tylenol', 'advil cold and flu', 'advil']
# [-0.013514948, -0.023671674, -0.010839173]
# ['pure life', 'gatorade', 'powerade', 'power']
# []
# ['molson']
# []
# ['water']
# []
# ['water']
# []
# ['water']
# [-0.01690894, -0.01351841, -0.044615943, 0.13887985, 0.019152299, 0.0048425104, -0.11555544, 0.03378132, 0.02679677, 0.10941565, -0.030259022, -0.07643568, 0.027008347, -0.098228864, 0.0106223, 0.21614]
# ['water', 'gatorade', 'bread', 'dempster', 'veggie dogs', 'basil', 'tissue', 'flour', 'horseradish', 'cashew milk', 'rice milk', 'natura', 'kimchi', 'nom shin', 'shin', 'aveeno balm', 'silk']
# [-0.01690894, -0.01351841, -0.044615943, 0.13887985, 0.019152299, 0.0048425104, -0.11555544, 0.03378132, 0.02679677, 0.10941565, -0.030259022, -0.07643568, 0.027008347, -0.098228864, 0.0106223, 0.21614]
# ['water', 'montellier', 'egg whites', 'spinach', 'chickpea', 'avocado', 'sweet potatoes', 'butternut squash', 'cous cous', 'couscous', 'greek yougurt', 'lettuce', 'beet', 'cookies', 'crackers', 'apple', 'rice cakes']
# [-0.010839173]
# ['water', 'liberte']
# [-0.013514948, -0.023671674, -0.010839173]
# ['water', '7 up', "po'", 'pop']
# [0.0014362634, -0.01328694, -0.044653364, 0.13880935, 0.019830279, 0.0046907538, -0.14454566, 0.04501414, 0.015041888, 0.10941853, -0.030302342, -0.07639, 0.026980197, -0.09821305, 0.06560709, 0.022348125, -0.010823835]
# ['spring water', 'borax', 'manuka', 'waffles', 'garbage bags', 'organic pasta', 'organic molisana', 'organic vita sana', 'dish soap', 'pickels', 'silver hills', 'sprouted wheat', 'salami', 'figs', 'wine', 'natural spring water', 'black label', 'banana']
# [0.109524556, 0.015015273, 0.044671305, -0.14454001, 0.004852889, 0.019152299, 0.13887985, -0.044132903, -0.013432669, -0.02365179, -0.01088622]
# ['water case', 'masks', 'facial tissue', 'qtips', 'cotton swabs', 'cappuccino', 'disinfecting wipes', 'lysol', 'brocolli', 'tomatoes', 'ice tea', 'prune juice']
# [0.044735733, -0.1445247, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839181]
# ['water', 'sangria', 'boisson sangria', 'cheese', 'buttermilk', 'cucumbers', 'duncan hinea', 'duncan hines', 'chips', 'cake mix']
# [-0.01690894, -0.01351841, -0.044615943, 0.13887985, 0.019152299, 0.0048425104, -0.11555544, 0.03378132, 0.02679677, 0.10941565, -0.030259022, -0.07643568, 0.027008347, -0.098228864, 0.0106223, 0.21614]
# ['water', 'wchips', 'chips', 'kettle chips', 'eggs', 'large eggs', 'wraps', 'buns', 'garlic bread', 'garlic loaf', 'burgers', 'smokies', 'hotdog buns', 'tostitos', 'ciabata', 'salami', 'sharp cheddar']
# [0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'milk', 'milk 2%', 'pepperettes', 'crave', 'reese']
# [0.0014362634, -0.01328694, -0.044653364, 0.13880935, 0.019830279, 0.0046907538, -0.14454566, 0.04501414, 0.015041888, 0.10941853, -0.030302342, -0.07639, 0.026980197, -0.09821305, 0.06560709, 0.022348125, -0.010823835]
# ['water', 'crackers', 'stone wheat', 'ritz', 'maia', 'maria', 'ichiban', 'intant noodles', 'macaroni & cheese', 'corn flakes', 'rice krispies', 'juice boxes', 'rice cereal', 'potatoe', 'bananas', 'ibprofan', 'acetaminophen extra strength 500mg', 'dish soap']
# [0.044735733, -0.1445247, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839181]
# ['nestles water', 'kale chard', 'organic blueberries', 'organic bananas', 'arla cream cheese', 'natures path heritage flakes', 'eden pizza sauce', 'pizza sauce', 'ladies underwear', 'baleine sea salt']
# [-0.0074324184, -0.01348428, -0.044633664, 0.13887261, 0.01949299, 0.0048850477, -0.14455229, 0.04486737, 0.01504347, 0.10941853, -0.030302342, -0.07639, 0.026978148, -0.09823241, 0.0654905, -0.14902768, 0.11934508, 0.0004743798, -0.00091365026, -0.01855421, -0.010832924]
# ['water', 'taco', 'canadian ice cream', 'turky sasage', 'turky sasage pc', 'noodles', 'sasala', 'salsa', 'soyasorce', 'soya sorce', 'oil', 'apple cider vineger', 'canadian apple cider vineger', 'always', 'always no wings', 'wipes', 'baby wipes', 'face clener', 'face clener spray', 'face clener spry', 'face clener liduid', 'face clener liguid']
# [-0.023671674, -0.010839173]
# ['water', 'instant coffee', 'chicken']
# [-0.010839173]
# ['water', 'oatmeal']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'juice box', 'hand soap', 'hand soap foaming', '6 inch red velvet cake']
# [0.0585129, -0.013565455, -0.04474148, 0.13874234, 0.01951663, 0.0053010043, -0.14398086, 0.044670034, 0.014861106, 0.10960494, -0.030277256, -0.07636762, 0.027035998, -0.09778257, 0.0656901, -0.14884715, 0.119556464, 0.00081246963, -0.0006687348, -0.07559322, 0.06765719, 0.10814354, 0.07417332, 0.0029579801, 0.11884344, 0.005375552, -0.010839173]
# ['water', 'potato patties', 'breakfast potatos', 'clamatoe', 'clamato, extra spicy', 'clam juice', 'clamchowder', 'muffin mix', 'sweetner', 'chip dip', 'lays', 'cookies lemmon', 'spinage', 'bread', 'ground beef regular', 'beef ground', 'soup mix', 'spring greens', 'spinach', 'cheese', '10', 'cola zero', 'ice tea', 'sugar', 'pc sugar substitute', 'date squares', 'bacon', 'hash browns']
# [-0.0074324184, -0.01348428, -0.044633664, 0.13887261, 0.01949299, 0.0048850477, -0.14455229, 0.04486737, 0.01504347, 0.10941853, -0.030302342, -0.07639, 0.026978148, -0.09823241, 0.0654905, -0.14902768, 0.11934508, 0.0004743798, -0.00091365026, -0.01855421, -0.010832924]
# ['water', 'toliet paper', 'paper towel', 'paper', 'wipes', 'bananas', 'chicken', 'parmesan & hard cheese', 'hard cheese', 'salad', 'arugala', 'cucumbers', 'kale crackers', 'turkey', 'avocado', 'kiwi', 'hemp', 'spinach', 'apples', 'hummus', 'baby carrots', 'seaweed']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'chips', 'salt and vinegar chips', 'popcorn', 'dill']
# [-0.010839173]
# ['water', 'coke']
# [-0.013514948, -0.023671674, -0.010839173]
# ['water', 'coca cola', 'chicken breast', 'pork chops']
# [-0.01690894, -0.01351841, -0.044615943, 0.13887985, 0.019152299, 0.0048425104, -0.11555544, 0.03378132, 0.02679677, 0.10941565, -0.030259022, -0.07643568, 0.027008347, -0.098228864, 0.0106223, 0.21614]
# ['natural spring water case', 'blueberries', 'caesar dressing', 'healthy skin anti wrinkle cream', 'healthy skin face lotion', 'soft & thick toilet paper, 12 rolls= 24', 'two scoops raisin bran cereal', 'ziploc', 'lettuce', 'granulated white sugar', 'package of coconut', 'unsweetened coconut', '14 grains whole wheat bread', 'tide laundry detergent', 'coffee pods', 'chicken broth', 'european wieners']
# [0.02701495, -0.07638936, -0.030299965, 0.10947381, 0.01500214, 0.044689193, -0.14454566, 0.00507989, 0.01911949, 0.13887727, -0.04461958, -0.013513082, -0.023671674, -0.010839173]
# ['water', 'banana', 'lime yogurt', 'strawberry', 'pc strawberries', 'bagels', 'silver hills', 'chocolate soy', 'bread', 'cheese', 'cheese slices', 'hummus', 'carrots', 'cucumber', 'yogurt greek']
# [0.014987758, 0.044699874, -0.14454566, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671672, -0.010839172]
# ['water', 'beef broth', 'patotes', 'potatoes', 'ground beef', 'olive oil butter', 'breakfast sausage', 'breakfast patty', 'yoplait', 'mandarin', 'fruit cup']
# [0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'egg whites', 'original smokies', 'gillette', 'almonds', 'halibut', 'dishwashing']
# [0.14862445, -0.013544901, -0.044613734, 0.13889168, 0.019688107, 0.0048411507, -0.14455226, 0.04490443, -0.09576736, -0.13429946, 0.12813479, -0.07639, 0.02703633, -0.098247066, 0.06543887, -0.14900543, 0.1193726, 0.00047561486, 0.09731776, 0.07963361]
# ['water', 'chicken', 'cheddar', 'gluten free bagels', 'gluten free pizza', 'tofu', 'bok choy', 'rice', 'broccoli', 'peppers', 'vegetables', 'stir fry', 'julienne carrots', 'egg noodle', 'chicken thigh', 'andalou', 'frozen peaches', 'frozen strawberries', 'milk', 'orang', 'orange juice']
# [0.039555587, 0.063418895, -0.067303605, 0.118774265, 0.0028439173, 0.073826455, 0.10750773, 0.067360856, -0.075961284, -0.00091365026, 0.00064578117, 0.11979719, -0.14856936, 0.066122286, -0.09790076, 0.027137853, -0.0762895, -0.029222138, 0.10953073, 0.015211765, 0.044689186, -0.14456539, 0.0050712805, 0.019235507, 0.13887523, -0.044624854, -0.013409988, 0.17137125, -0.007451587, -0.1025122, -0.031080913, 0.19912922, 0.054504436, -0.12554945, 0.12851942, -0.0726348, 0.014028781, -0.2191345, -0.0397139, -0.03518268, -0.020881342, -0.017859928, 0.047150914, 0.0005827379, -0.011384921, 0.00032862974, -0.0462414, 0.07222343, -0.050993916, 0.110414274, 0.002862476, 0.0073833317, -0.23793864, 0.025347725, -0.032469146, 0.091058895, -0.0074796826, 0.03465436, -0.010826688]
# ['water', 'snack bags', 'toilet paper', 'paper towel', 'ketchup', 'mustard', 'kraft dinner', 'gold fish', 'ham', 'canned corn', 'hashbrowns', 'cheddar soup', 'marble cheese', 'oil', 'becel', 'chicken', 'chicken thighs', 'flank steak', 'coleslaw', 'romaine', 'm and m', 'smarties', 'fruit snacks', 'welches', 'broccoli', 'delissio', 'eggs', 'turkey', 'mini bagels', 'ice burg', 'iceburg', 'green leaf lettuce', 'crest', 'lemonade', '7 up', 'diet', 'sprite', 'gatorade', 'wheat crunch', 'honey', 'dove soap', 'dove sensitive skin', 'garlic powder', 'onion powder', 'corn starch', 'kool aid', 'jube jube', 'miss vickys', 'ichiban', 'sour cream', 'lactose free', 'green pepper', 'green onion', 'cauliflower', 'pepperoni', 'grimms', 'chicken wings', 'ranch', 'wavy chips', 'lysol wipes']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'pizza pocket', 'buns', 'chips', 'pepperoni']
# [-0.0074324184, -0.01348428, -0.044633664, 0.13887261, 0.01949299, 0.0048850477, -0.14455229, 0.04486737, 0.01504347, 0.10941853, -0.030302342, -0.07639, 0.026978148, -0.09823241, 0.0654905, -0.14902768, 0.11934508, 0.0004743798, -0.00091365026, -0.01855421, -0.010832924]
# ['nestle water', 'alcohol', 'baby wipes', 'toilet paper', 'kettle', 'dish soap', 'oats', 'butter', 'crackers', 'cream cheese', 'vega', 'avocado', 'newmans', 'carrots', 'glutinous rice', 'rice', 'carnation milk', 'evaporated milk', 'potatoes', 'bacon', 'corn', 'lays']
# [-0.013514948, -0.023671674, -0.010839173]
# ['water', 'bai', 'barista soy', 'almond milk']
# []
# ['aquafina']
# [0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['aquafina', 'coca cola', 'ginger ale', 'quaker', 'dark chocolate granola bars', 'air fresheners', 'air fresheners stick on']
# [-0.076438285, -0.030349428, 0.10943732, 0.015076419, 0.044719342, -0.14454566, 0.0048425104, 0.019362226, 0.13888659, -0.044556446, -0.013468326, -0.023665152, -0.010839173]
# ['water', 'chicken breast', 'chicken drumstivk', 'grapes', 'jam', 'smoothy mix', 'smoothy', 'cake', 'beef jerky', 'bacon', 'corn', 'cereal', 'creamer', 'milk']
# [-0.14454566, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['bottled water case', 'diet coke case', 'pc sparkling lemonade', 'arizona green tea', 'english muffin', 'brussel sprouts', 'mennonite style farmers sausage', "campbell's vegetable soup", 'beef broth']
# [0.02701495, -0.07638936, -0.030299965, 0.10947381, 0.01500214, 0.044689193, -0.14454566, 0.00507989, 0.01911949, 0.13887727, -0.04461958, -0.013513082, -0.023671674, -0.010839173]
# ['kitkat', 'aero bar, king size case', 'aero bar', 'bread', 'macaroni', 'ice cream', 'ice cream cone', 'tomato basil soup', 'tomato soup', 'soup', 'juice', 'juice club', 'shelf stable juices', 'syrup', 'coffee']
# [-0.023671674, -0.010839173]
# ['eska', 'dascani', 'dried mango']
# [-0.013514948, -0.023671674, -0.010839173]
# ['becks', 'dealcoholised sparkling wine, white', 'dealcoholised beer', 'no alcohol beer']
# [0.044735733, -0.1445247, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839181]
# ['becks', 'baby gourmet', 'ziploc', 'tomato', 'mini hummus', 'hummus', 'bean salad', 'quinoa salad', "shepherd's pie", 'chicken']
# [-0.22729617, -0.013550967, -0.044588435, 0.13887683, 0.01965471, 0.0047989488, -0.14453398, 0.045199446, 0.015039983, -0.13429186, 0.008322228, -0.16288689, 0.026978975, -0.098226994, 0.06558993, -0.1490341, 0.1193161, 0.0005026174, -0.00091365026, -0.075938635, 0.1489742, 0.09305835]
# ['lean', 'vicks', 'texas toast', 'grape', 'powerade', 'simply ageless', 'simply', '205', '210', 'nail polish remover', 'acetone', 'polish remover', 'quo', 'quick dry', 'sally hansen', 'sally hansen insta', 'insta dri', 'top coat', 'french', 'hamburger bun', 'ballpark classics limited edition 8 hamburger buns', 'tomato', 'red onion']
# [-0.013514948, -0.023671674, -0.010839173]
# ['lean cuts wet', 'tortilla & wraps', 'rib', 'cherry coke']
# [0.0585129, -0.013565455, -0.04474148, 0.13874234, 0.01951663, 0.0053010043, -0.14398086, 0.044670034, 0.014861106, 0.10960494, -0.030277256, -0.07636762, 0.027035998, -0.09778257, 0.0656901, -0.14884715, 0.119556464, 0.00081246963, -0.0006687348, -0.07559322, 0.06765719, 0.10814354, 0.07417332, 0.0029579801, 0.11884344, 0.005375552, -0.010839173]
# ['mama', 'passata', 'iogo', 'yogurt', 'garlic peas', 'coconut miracle oil', 'make up remover', 'make up remover micellar', 'make up micellar', 'q tips', 'nesquik', 'mushroom knorr', 'mushroom tablet', 'mushroom', 'mushroom broth', 'mushroom cubes', 'knorr cubes', 'cranberry', 'cranberry sunrype', 'toothpaste crest', 'tofu', 'celery', 'dill pickles', 'mayonnaise light 1 2 fat', 'parmesan', 'parmesan pc', 'taco seasoning', 'salsa']
# [-0.013514948, -0.023671674, -0.010839173]
# ['bottled water', 'calmag', 'sisu cal', 'sisu']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'sugar cubes', 'romaine', 'mens diapers', 'topopthpaste']
# []
# ['bière sans alcool']
# [0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['naya', 'framboise', 'bleuets', 'dainty', 'fiz dainty', 'riz dainty']
# [0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['biere', 'fromage cottage 1%', 'fromage allege', 'fromage', 'pois chiche', 'hummus', 'napkin']
# []
# ['water']
# []
# ['water']
# []
# ['eau']
# [-0.010839173]
# ['water', 'shampoo']
# [-0.010839173]
# ['water', 'ground beef rolls']
# [-0.010839173]
# ['eau', 'berska']
# [-0.013514948, -0.023671674, -0.010839173]
# ['water', 'paper paltes', 'paper plates', 'royal plates']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['bottled water', 'brita filters', 'chicken stock', 'juice', 'butter']
# [-0.03457117, -0.013463832, -0.044617373, 0.13887985, 0.01914507, 0.0050102943, -0.14388406, 0.044725604, 0.015025198, 0.10941853, -0.030266779, -0.07633359, 0.1373406, 0.16068412, 0.049073577, -0.14896625, 0.11936081, 0.00048351462, -0.00089882594, -0.07588928, 0.06730738, 0.10756424, 0.073713616, 0.0027895262, 0.11872665, -0.06716446, 0.0190394, 0.054321274]
# ['eau', 'oeufs', 'oeuf', 'brocolis', 'choux fleur', 'poulet', 'ficello', 'oasis', 'nutri grains', 'ritz', 'cristie', 'minces aux légumes', 'poivrons', 'choux bruxelle', 'salade de poulet', 'raisins verts', 'betty crocker', 'betty crocker purée', 'pommes de terre en purée', 'cottage', 'café', 'café en grains', 'café le choix du président', 'café van houtte', 'crème glacée', 'crème glacée caramel', 'melon', 'framboises', 'haricots']
# [-0.013514948, -0.023671674, -0.010839173]
# ['water', 'eggs', 'slice cheese', 'toilet paper']
# [0.044735733, -0.1445247, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839181]
# ['water', 'phapdelphia cheese', 'philadelphia cheese', 'pasta sauce', 'chicken parmesan', 'chicken parmigiana', 'cottage cheese', 'salad kit', 'caesar salad', 'organic strawberry']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'mortadella', 'provolone cheese', 'crackers', 'milk']
# [-0.010839173]
# ['bottled water', 'bleach']
# [0.014987758, 0.044699874, -0.14454566, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671672, -0.010839172]
# ['water', 'coke', 'grapes', 'gogo', 'gogo apple sauce', 'cookies', 'carrots', 'pasta', 'pasta sauce', 'meat ball', 'meatballs']
# [-0.22729617, -0.013550967, -0.044588435, 0.13887683, 0.01965471, 0.0047989488, -0.14453398, 0.045199446, 0.015039983, -0.13429186, 0.008322228, -0.16288689, 0.026978975, -0.098226994, 0.06558993, -0.1490341, 0.1193161, 0.0005026174, -0.00091365026, -0.075938635, 0.1489742, 0.09305835]
# ['water', 'caffeine free diet coke', 'diet sprite', 'sprite', 'diet coke', 'cplus', 'c plus', 'c plus orange soda', 'pop', 'pre popped', 'c plus pop', 'orange soda', 'diet pop', 'diet soda', 'soda', 'sliced ham', 'country harvest bread', 'dempsters bread', 'no name peanut butter', 'lysol toilet bowl cleaner', 'dishwasher tabs', 'frozen macaroni', 'stouffers']
# [-0.15274855, -0.1489943, 0.06556135, -0.09826169, 0.026968414, -0.07612399, -0.029418845, -0.07423447, -0.09579184, 0.033638023, -0.14455742, 0.0048909653, 0.019325765, 0.1390259, -0.04461707, -0.013519355, 0.15371346, 0.0011749467, -0.000735193, -0.075718924, -0.024480535, -0.03249931, 0.091061346, -0.0072204713, 0.14911218, -0.1488433, -0.1026793, -0.007835369, -0.060168985, 0.063239366, -0.06677694, 0.119570136, 0.0031684134, 0.07400925, 0.1078884, 0.09936342, 0.06293594]
# ['water', 'pepsi', 'gingerale', 'perier', 'carbonated water', 'salami', 'balogna', 'buns', 'kaiser buns', 'chicken noodle soup', 'lunch snacks', 'bear paws', 'chips', 'grapes', 'nectarine', 'ceasar salad', 'kielbassa', 'kielbassa coil', 'bread', 'bananas', 'juice box', 'kolbassa', 'chicken broth', 'onions', 'potatoes', 'toilet paper', 'eggs', 'rice', 'frozen vegetables', 'pickles', 'vachon', 'cheese', 'green onion', 'cat litter', 'mirin', 'chinese cooking wine', 'pierogies', 'perogies']
# [0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'corn', 'carrots', 'fruit tray', 'breakfast', 'tea biscut']
# [-0.010839173]
# ['bottled water', 'chicken thighs']
# [0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'black diamond combos', 'cheerios', 'janes', 'robin hood flour', 'ham steak', 'hot chocolate', 'keurig']
# [-0.010839173]
# ['water', 'dishwasher']
# [-0.076438285, -0.030349428, 0.10943732, 0.015076419, 0.044719342, -0.14454566, 0.0048425104, 0.019362226, 0.13888659, -0.044556446, -0.013468326, -0.023665152, -0.010839173]
# ['water bottle', 'oats', 'chia seeds', 'cabbage', 'green peppers', 'cooking spinach', 'banana', 'ice burg lettice', 'ice burg', 'lettuce', 'eska', 'black beans', 'no name', 'no name beans']
# [0.014987758, 0.044699874, -0.14454566, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671672, -0.010839172]
# ['water', 'parchment paper', 'berry', 'fruit', 'ground beef', 'sugar free snack', 'sugar free granola bar', 'eggs', 'potato', 'pasta sauce', 'pasta noodles']
# [-0.017146377, -0.10282323, -0.007827896, -0.059966467, 0.063390404, -0.06703027, 0.118754, 0.002916975, 0.073587425, 0.10766462, 0.06725632, -0.07606954, -0.0010219989, 0.00040644052, 0.060067438, 0.022659069, 0.12322588, -0.09803922, 0.027181447, -0.07537511, -0.029850926, 0.10967983, 0.015444737, 0.045040667, -0.14405629, 0.004874302, 0.019033995, 0.13979846, -0.044678427, -0.013554733, 0.08110734, -0.116090514, 0.0685646, 0.15640146, -0.14151832, 0.009322164, -0.1464126, 0.050197393, 0.078802384, -0.15010703, 0.1518607, 0.034103543, 0.054162033, -0.1260519, 0.12830712, -0.07290014, 0.014117032, -0.21895523, 0.15762514, 0.08323521, 0.101512566, -0.017790873, 0.047341518, 0.17187911, 0.09906464, -0.2664813, -0.046193637, 0.07166599, -0.051590946, 0.1102339, 0.0028573703, 0.0076654283, -0.2374233, 0.025863979, 0.12521495, 0.14210464]
# ['water', 'bread', 'bagel', 'pogo', 'mr.noodles', 'english muffin', 'luncheon meat', 'lunch meat', 'sliced cheese', 'ham', 'apple', 'banana', 'juice', 'juice box', 'extra strenght back muscle', 'back relief', 'back muscle pain', 'white bread', 'brown bread', 'water melon', 'fruits', 'mcintosh apples', 'juice boxes', 'fruit juice boxes', 'carrots', 'cereals', 'cereals vanila rice krispies', 'chicken', 'mayo', 'cheese and crackers', 'lactose free milk', 'honey', 'coffee cups', 'coffee paper cups', 'coffee cups with lids', 'paper cups with lids', 'toilet paper', 'paper towels', 'matches', 'take out coffee cups and lids', 'paper cups', 'paper mugs', 'paper', 'paper cups lids', 'coffee cups with litds', 'pepercoffee cups with litds', 'peper coffee cups with litds', '120z coffee cup w lid', '120z coffee cup', '120z coffee cup with lid', '120oz coffee cup with lid', '120oz coffeepaper cup with lid', '120oz coffee paper cup with lid', '12oz coffee cup with lid', '12oz coffee cup', '12oz coffee', '12oz paper cupscoffee', '12oz paper cups', '12oz paper cups eith lids', '12oz paper cups with lids', '12oz coffee cups with lid', 'cups', 'cups with lids', 'cups,plates', 'cup', 'paper cup', 'paper plate']
# []
# ['real canadian water']
# []
# ['water']
# []
# ['water']
# [-0.013514948, -0.023671674, -0.010839173]
# ['water', 'yellow beans', 'canned', 'soup']
# [-0.09825402, 0.027019612, -0.07638238, -0.030302342, 0.10941853, 0.015025198, 0.044689193, -0.14448667, 0.0048370697, 0.019140474, 0.13878547, -0.04463267, -0.013514948, -0.023671674, -0.010798492]
# ['water', 'eggs', 'milk', 'mazola', 'olive oil', 'extra virgin olive oil', 'pampers', 'aveeno', 'aveeno baby', 'yogurt', 'igo yogurt', 'iogo yogurt', 'pineapple', 'watermelon', 'blueberries', 'kiwi']
# [-0.21562879, -0.013449475, -0.044623543, 0.13885213, 0.019232525, 0.004855756, -0.14385046, 0.044622727, 0.015025198, 0.109441064, -0.029922236, -0.07637817, 0.027043546, -0.09823188, 0.06548556, -0.14902948, 0.119367085, 0.0004176653, -0.00059038494, -0.07561954, 0.06788366, 0.1887145, -0.010558398]
# ['water', 'pop', 'coke', 'lattice', 'fruits and vegetables', 'lettuce and tomatoes', 'eggs', 'milk', 'cream', 'red bull', 'crush', 'chips', 'snack bars', 'hotdog buns', 'burger buns', 'wieners', 'lunch mate', 'brownies', 'cake', 'drinks', 'laundry detergent', 'fabric softener', 'sellet', 'vegetables']
# [-0.023671674, -0.010839173]
# ['water', 'axe body wash', 'barbisol']
# [-0.01690894, -0.01351841, -0.044615943, 0.13887985, 0.019152299, 0.0048425104, -0.11555544, 0.03378132, 0.02679677, 0.10941565, -0.030259022, -0.07643568, 0.027008347, -0.098228864, 0.0106223, 0.21614]
# ['water', 'coffee mate', 'philidelphia', 'coffeemate', 'nescafe', 'oatmeal', 'ground beef', 'cucumber', 'red oniion', 'onions', 'hawkins cheezies', 'sour dough', 'ktchup', 'ketchup', 'lettuce', 'ice cream', 'chapmans ice cream']
# [-0.023671674, -0.010839173]
# ['case water', 'bagels', 'bread']
# [0.0038111245, -0.0009846962, 0.0003889287, 0.11937966, -0.14902948, 0.06548712, -0.09824341, 0.027215723, -0.0755177, -0.030191496, 0.10945788, 0.014984888, 0.044884916, -0.14444871, 0.0053134076, 0.01925817, 0.13885167, -0.044224247, -0.013236468, -0.0074412865, 0.067342535, 0.107436225, 0.029060697, -0.09362363, -0.05141988, 0.110187575, 0.002829252, 0.00734705, -0.23736587, 0.025477832, -0.032352634, 0.050734136, 0.0011917986, 0.063331686, -0.14725435, -0.102968745, -0.008044168, -0.05984464, 0.064070195, -0.06714499, 0.11907527, -0.06721938, -0.010680665]
# ['natural spring', 'club soda', 'apple cider vinegar', 'apple juice', 'gusher', 'krave', 'ben and jerry', 'no name chips', 'goldfish', 'freezer bag', 'bagel', 'bagel cheese', 'bread', 'banana', 'berries', 'watermelon', 'bear paw', 'alphaghetti', 'beefaroni', 'kolbassa', 'fruit cup', 'tide', 'bounty', 'yup', 'yop', 'cucumber', 'janes', 'pc chicken', 'spring roll', 'tortilla wraps', 'lettuce', 'bacon bits', 'ranch', 'caesar', 'turkey', 'ready crisp', 'eggs', 'breakfast sausage', 'tomato', 'hashbrown', 'cavendish', 'hash brown', '9 minute', 'mccain']
# [-0.22729617, -0.013550967, -0.044588435, 0.13887683, 0.01965471, 0.0047989488, -0.14453398, 0.045199446, 0.015039983, -0.13429186, 0.008322228, -0.16288689, 0.026978975, -0.098226994, 0.06558993, -0.1490341, 0.1193161, 0.0005026174, -0.00091365026, -0.075938635, 0.1489742, 0.09305835]
# ['water', 'strawberries', 'made good pizza', 'grapes', 'bagel bites', 'lime chips', 'salsa', 'corn pops', 'turkey bacon', 'bacon', 'aaples', 'salad dressing', 'peppers', 'tomatoes', 'snap peas', 'nectarines', 'ham', 'salad', 'raspberries', 'muffins', 'avacado', 'cereal', 'life']
# [0.013448459, -0.012916895, -0.0446471, 0.13886042, 0.019240241, 0.0048739295, -0.1444858, 0.04477911, 0.015005482, 0.10972213, -0.030333754, -0.0764381, 0.02715211, -0.09801244, 0.06535473, -0.14910549, 0.11944318, 0.0007309253, -0.0008540908, -0.07588921, 0.067311645, 0.107648976, 0.0735656, -0.012728424, -0.010839173]
# ['water', 'rice', 'mr noodles', 'asago dip', 'meat', 'stir fry', 'stir fry strips', 'beef stewing cubes, boneless', 'pineappl', 'tortilla', 'cashews', 'chicken kabobs', 'chicken breast', 'popcicles', 'freezies', 'cheese', 'apples', 'cucumber', 'instabt coffee', 'pringle cups', 'pringles', 'granola bars', 'granola bars caramel nut', 'orange joice', 'protein granola bars', 'yogurt']
# [-0.035127673, -0.013373278, -0.04465127, 0.13883625, 0.020061176, 0.004796248, -0.14453974, 0.04503237, 0.015044337, 0.10941853, -0.030302342, -0.07639, 0.026999108, -0.09824943, 0.06540885, -0.14902051, 0.11936131, 0.1592674, -0.010839173]
# ['water case', 'almond milk', 'milk', 'dill pickles', 'hot peppers', 'bell peppers', 'yop case', 'yop', 'yop yogurt', 'yops', 'fruit cups', 'juice boxes', 'raspberries', 'blueberries', 'bananas', 'ceasar dressing', 'ketchup', 'potatoes', 'chips', 'bread']
# [0.05276396, 0.11941049, -0.14893588, 0.06542344, -0.09822008, 0.027076384, -0.076124914, -0.029837089, 0.10946022, 0.014982632, 0.044784546, -0.14453916, 0.0048822016, 0.018969378, 0.13892359, -0.044594366, -0.013380842, -0.03472196, -0.15917028, -0.018285643, 0.046786446, -0.019464077, 0.00784407, -0.23744994, 0.025504524, -0.03233625, 0.090851806, -0.007169024, 0.14938958, -0.14843509, -0.10246144, -0.007752521, -0.059591264, 0.06389424, -0.0665247, 0.11875862, 0.0028909836, 0.07392782, 0.1567059, 0.06456667]
# ['water', 'eggs', 'bacon', 'fruit salad', 'eggos', 'waffles', 'thick waffles', 'front loops', 'froot loops cereal', 'orange juice', 'milk', 'jammers', 'turkey breast', 'salami', 'oranges', 'grapes', 'watermelon', 'canalope', 'bananas, bunch', 'strawberries', 'raspberries', 'lettuce & leafy vegetables', 'celery', 'broccoli', 'potatoes', 'canned corn', 'lean ground beef', 'pork chops', 'hot pockets', 'pizza pockets', 'lasagna', 'weiners', 'hot dogs', 'cheese slices', 'lime', 'lemon', 'cheese whiz', 'mini wheats', 'ketchup', 'syrup', 'mr. noodle']
# [0.1528267, -0.013467339, -0.04470051, 0.13882425, 0.019753195, 0.004784764, -0.14453161, 0.03402092, -0.095769934, -0.074279845, -0.03033181, -0.07639, 0.02699045, -0.09822421, 0.0654267, -0.14905857, 0.09616288, 0.063003704]
# ['water', 'frozen vegetables', 'bread', 'kimchi noodles', 'pineapple can', 'carrots', 'icing sugar', 'sour cream', 'salt', 'pepper', 'trifle cake pan', 'trifle bowl', 'pizza pockets', 'choclate milk', 'facial tissue', 'eggs', 'cream cheese', 'cocoa', 'flour']
# [0.1528267, -0.013467339, -0.04470051, 0.13882425, 0.019753195, 0.004784764, -0.14453161, 0.03402092, -0.095769934, -0.074279845, -0.03033181, -0.07639, 0.02699045, -0.09822421, 0.0654267, -0.14905857, 0.09616288, 0.063003704]
# ['water', 'juice boxes', 'juice boxes strawberry banana', 'tomatoes', 'cream cheese', 'chips', 'laundry soap', 'laundry detergent', 'white vinegar', 'peaches', 'bananas', 'plums', 'frozen berries', 'chicken wings', 'band aids', 'dish sponges', 'brita', 'potatoes', 'all purpose cleaner']
# [0.0014362634, -0.01328694, -0.044653364, 0.13880935, 0.019830279, 0.0046907538, -0.14454566, 0.04501414, 0.015041888, 0.10941853, -0.030302342, -0.07639, 0.026980197, -0.09821305, 0.06560709, 0.022348125, -0.010823835]
# ['water', 'doritos', 'muffins', 'mini muffin', 'milk', 'egg', 'grapes', 'hot dog', 'nibs', 'beer', 'dino', 'garlic', 'red pepper', 'apples', 'gala apple', 'muffin', 'italiano', 'colgate kids']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'lunchable', 'koba', 'meat', 'hamburger']
# [-0.14454566, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['yop', 'craquelins et biscuits', 'craquelins', 'jus', 'patte', 'poulet', 'poisson', 'eponge', 'mio']
# [-0.013514948, -0.023671674, -0.010839173]
# ['yop', 'épice bagel', 'bagel', 'fromage a la crème']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['yoplait', 'wraps', 'peas, beans & corn', 'canned corn', 'eggs']
# [-0.0074324184, -0.01348428, -0.044633664, 0.13887261, 0.01949299, 0.0048850477, -0.14455229, 0.04486737, 0.01504347, 0.10941853, -0.030302342, -0.07639, 0.026978148, -0.09823241, 0.0654905, -0.14902768, 0.11934508, 0.0004743798, -0.00091365026, -0.01855421, -0.010832924]
# ['yoplait', 'nescafe rich', 'peppers', 'green grapes', 'grapes', 'bleberries', 'blueberries', 'cream cheese', 'cream cheese strawberry', 'flour wraps', 'butter', 'gatorade', 'chicken strips', 'shredded cheese', 'sliced cheddar', 'milk', 'eggs', 'bread', 'pancakes', 'pots and pans', 'keurig', 'keurig single serve coffee maker']
# [-0.030296177, 0.10960891, 0.014882498, 0.044643596, -0.14455914, 0.0048425104, 0.019152312, 0.13927871, -0.044562627, -0.013485333, -0.02367525, -0.010830897]
# ['yop', 'litière', 'chips', 'lays', 'ruffle', 'fromage marbre', 'blocs de fromage', 'brochette poulet', 'coke', 'coke canette', 'eau saveur', "caisse d'eau", "bouteille d'eau"]
# [0.057922903, -0.07603012, -0.00090859225, 0.00048269628, 0.11938602, -0.14903633, 0.065452404, -0.0982359, 0.026988894, -0.16299511, 0.008137922, -0.1344311, 0.015464885, 0.044998508, -0.14421424, 0.005373794, 0.019391056, 0.13909014, -0.044499733, -0.013358066, -0.227345, 0.04806956, 0.11438431, -0.13776827, 0.0068189166, -0.266599, -0.04626691, 0.071943924, -0.05145035, 0.11053248, 0.0030944138, 0.007550923, -0.23753516, 0.034364965, -0.08780278, -0.035571985, -0.007391322, 0.1491032, -0.14849937, -0.10255291, -0.007480968, -0.0599786, 0.063434295, -0.06702538, -0.009230426, -0.0015831804]
# ['yoplait', 'oikos', 'cheese strin', 'cheese', 'cheese string', 'organic cracker', 'triscuit', 'crackers', 'cracker', 'cucumber', 'potatoe', 'ginger', 'garlic', 'garlic clove', 'carrot', 'apple', 'peach', 'annies', 'banana', 'avocado', 'blueberry', 'plum', 'braggs', 'waste management', 'waste management spray', 'spray', 'wm spray', 'odour disposer', 'scicorp', 'odour', 'wm', 'cupcake liner', 'cupcake', 'baking cup', 'organic cookie', 'digestive', 'bage', 'bagel', 'cookie', 'chips', 'chip', 'scrubber', 'sponge', 'garbage bad', 'garbage bag', 'bento', 'organic cheerios']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['eska', 'weston white bread', 'cougreut', 'cheese', 'shredded swiss cheese']
# [-0.010839173]
# ['eska', 'parmesan']
# [-0.076438285, -0.030349428, 0.10943732, 0.015076419, 0.044719342, -0.14454566, 0.0048425104, 0.019362226, 0.13888659, -0.044556446, -0.013468326, -0.023665152, -0.010839173]
# ['eska', 'tomatoes', 'dish soap', 'artichoke in water', 'artichoke', 'pita', 'greek pita', 'melba', 'diet pepsi', 'garbage bags', 'chocolate almonds', 'cheese', 'brie', 'olive oil']
# [-0.013514948, -0.023671674, -0.010839173]
# ['eau eska', 'fromage mozarella', 'peches', 'jus d’orange']
# [-0.013514948, -0.023671674, -0.010839173]
# ['bottled water', 'paper cups', 'paper. coffee cups', 'paper. coffee cups in store']
# [-0.013514948, -0.023671674, -0.010839173]
# ['eau', 'jus', 'jus orange', 'orange']
# [-0.013514948, -0.023671674, -0.010839173]
# ['water bottles', 'chicken', 'cream of chicken', 'palmolive']
# [0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['water', 'milk', 'cream', 'cereal', 'pasta', 'rice krispies']
# [0.0014362634, -0.01328694, -0.044653364, 0.13880935, 0.019830279, 0.0046907538, -0.14454566, 0.04501414, 0.015041888, 0.10941853, -0.030302342, -0.07639, 0.026980197, -0.09821305, 0.06560709, 0.022348125, -0.010823835]
# ['water bottles', 'coke', 'triscuit', 'butter', 'hardwood smoked thuringer sausage', 'cracker barrel', 'pringles', 'ed smith pie', 'activia', 'bins', 'jersey milk', 'oh henry', 'ice water', 'med ziploc freezer', 'ziploc freezer', 'tomato paste', 'president choice meduim heavy duty freezer', 'halloween']
# [-0.023671674, -0.010839173]
# ['boisson alcoolisée domingo à saveurs variées format économique', 'riz', 'riz dainty']
# [-0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['tums', 'york', 'brookside', 'fishermans friend', 'mints']
# []
# ['orange crush']
# [0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['iced tea', 'broccoli', 'bananas', 'butter', 'milk', 'ziploc', "orri's", 'mandarins']
# [0.109524556, 0.015015273, 0.044671305, -0.14454001, 0.004852889, 0.019152299, 0.13887985, -0.044132903, -0.013432669, -0.02365179, -0.01088622]
# ['beer', 'skyr', 'salmon', 'salmon maple', 'oats', 'salsa pc', 'salsa pc organics', 'webber omega', 'stevia', 'cat litter', 'cat food pate', 'organic eggs']
# [0.1027343, -0.09826384, 0.026932463, -0.07637632, -0.03031417, 0.10947662, 0.027213387, 0.03369798, -0.11555544, 0.00484047, 0.01917834, 0.13887765, -0.044686884, -0.013409289, -0.016904237, 0.0063354024, -0.16030991, -0.041321933, 0.016159281, 0.14957073, -0.148641, -0.102621876, -0.00800439, -0.059989892, 0.16692093, 0.11027876, 0.127667, 0.0026836917, 0.07373638, 0.10756606, 0.06727371, -0.0755253, 0.014441882, -0.014174385]
# ['g2', 'g zero', 'gatorade', 'ham', 'turkey', 'roast beef', 'crossiant', 'zero water', 'eggs', 'strawberry', 'apples', 'cheese', 'cheese slice', 'sausage rounds', 'hotdog buns', 'red pepper', 'banana', 'grapes', 'donuts', 'salad', 'buns', 'dinner rolls', 'carrots', 'yogurt', 'skyr yogurt', 'plain chips', 'chips', 'milk', 'cream', 'coffee', 'keto', 'mozerella', 'pizza cheese', 'saputo', 'cucumber']
# [-0.09825402, 0.027019612, -0.07638238, -0.030302342, 0.10941853, 0.015025198, 0.044689193, -0.14448667, 0.0048370697, 0.019140474, 0.13878547, -0.04463267, -0.013514948, -0.023671674, -0.010798492]
# ['g2', 'bread', 'bagels', 'cream cheese', 'turkey bacon', 'eggs', 'no yolk egg noodles', 'ground chicken', 'fruit', 'yogurt drinks', 'chip dip', 'detergent', 'paper towel', 'lunch mate', 'crackers', 'made good']
# [-0.0074324184, -0.01348428, -0.044633664, 0.13887261, 0.01949299, 0.0048850477, -0.14455229, 0.04486737, 0.01504347, 0.10941853, -0.030302342, -0.07639, 0.026978148, -0.09823241, 0.0654905, -0.14902768, 0.11934508, 0.0004743798, -0.00091365026, -0.01855421, -0.010832924]
# ['gatorade', 'perogie', 'skyr', 'strawberrie', 'strawberries', 'glasses', 'eyeglass', 'eye glass', 'vision', 'apples', 'corn flakes', 'milk 1', 'mandarin oranges', 'hot dog bun', 'english muffin', 'no name muffin', 'extra crisp', 'english', "president's choice english", 'risotto', 'doritos', 'ms vickie']
# [-0.023671674, -0.010839173]
# ['gatorade', 'potatoes', 'smarties']
# [-0.07351302, 0.119554125, -0.14905609, 0.065360636, -0.098216854, 0.027246438, -0.076000795, -0.029924713, 0.10940445, 0.015025198, 0.044637177, -0.144444, 0.005325264, 0.018977545, 0.13870133, -0.044749867, -0.013525081, -0.034594998, -0.0005103005, -0.07543612, 0.08482594, 0.09464057, -0.23670685, 0.02539488, -0.032325048, 0.09093178, -0.007259731, 0.1489539, -0.060706936, -0.022379527, 0.13681912, -0.059715547, 0.06355268, -0.06706006, 0.11956125, 0.0028026681, 0.073631614, 0.12803832, -0.01073257]
# ['mild sausage', 'hot sausage', 'philly steak', 'philly cheese steak', 'philly', 'sour cream', 'horse radish', 'horseradish pure', 'horseradish, extra hot', 'marinara', 'tomato marinara', 'full red', 'tomato sauce', 'marinara sauce', 'full red mari', 'philly beef', 'salt & pepper', 'salt', 'parsley', '1dedgree', '1 degree', '12 oz soup', '12 oz foam', '10 oz foam', '1st barbeque', '1st wing', '1st degree wing sauce', '1st degree', 'saucemaker', 'extra lean smoked turkey, full round', 'pasta sauce', 'roast beef', 'new york philly', 'medium ground beef tube', '12” tortillis', 'sauce', 'barbecue wing sauce', 'wing sauce', 'shrimp', 'mushrooms']
# [0.044735733, -0.1445247, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839181]
# ['pelligrino', 'water', 'chips snack', 'chips snack individual', 'party', 'party favours', 'table cloth party', 'plastic tablecover', 'command hooks', 'plastic table cobmver']
# [-0.010839173]
# ['san pellegrino', 'broccoli']
# []
# ['boison gazeuse']
# [0.053464323, -0.013323129, -0.04460168, 0.13887827, 0.019320933, 0.004838962, -0.14455259, 0.044690877, 0.014989821, 0.109607644, -0.030355357, -0.0036990698, 0.13752559, -0.14475119, 0.06531604, -0.14913276, 0.11945813, 0.0006633735, -0.0008641458, -0.07581164, 0.0673568, 0.10763977, 0.07358911, 0.0027833823, 0.03691316, -0.037719578]
# ['tzao', 'tazo', 'tazo mint', 'stash mint', 'mint tea', 'chapman cone', 'fruite', 'bread', 'allens', 'allens vinegar', 'clorox', 'cheese string', 'celery', 'brocolli', 'blueberries', 'asian noodle', 'haiku', 'sliced water chestnuts', 'young baby corn in brine', 'carrott', 'cream cheese', 'crunchie 4pk', 'icing sugar', 'gatorade', '1 cup', '1 cup storage', 'ziploc']
# [0.053464323, -0.013323129, -0.04460168, 0.13887827, 0.019320933, 0.004838962, -0.14455259, 0.044690877, 0.014989821, 0.109607644, -0.030355357, -0.0036990698, 0.13752559, -0.14475119, 0.06531604, -0.14913276, 0.11945813, 0.0006633735, -0.0008641458, -0.07581164, 0.0673568, 0.10763977, 0.07358911, 0.0027833823, 0.03691316, -0.037719578]
# ['crush', 'root beer', 'cola', 'chipa', 'cookies', 'chocolate milk', 'milk', 'butter', 'canned fruit', 'frozen veges', 'zucchini', 'bacon', 'pc spice blends', 'pepper', 'black pepper', 'speedstick', 'olay cleansing', 'goldfish', 'goldfish cheddar and sour cream', 'gap carrd', 'gap card', 'gap', 'cheese', 'cheese strings', 'mozza cheese', 'pepsi', 'unsalted butter']
# [-0.013514948, -0.023671674, -0.010839173]
# ['soda', 'gingerale', 'ice', 'pepsi']
# [-0.14454566, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['pelligrino', 'grapes', 'dates', 'ground beef', 'ground pork', 'pork', 't&t', 'buns', 'ground beef and pork']
# [0.044735733, -0.1445247, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839181]
# ['san pellegrino', 'pudding', 'budding ham', 'sliced ham', 'crispy baked products', 'crispy', 'prime fresh poultry products', 'prime', 'bulk foods', 'neocitran']
# []
# ['v8 cocktail']
# [-0.010839173]
# ['v8', 'cereal']
# [0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['tofu', 'classik dishwasher sanitizer', 'deli plastic container, clear 32oz', 'chopsticks', 'soy sauce', 'lysol', 'bleach']
# [-0.0074324184, -0.01348428, -0.044633664, 0.13887261, 0.01949299, 0.0048850477, -0.14455229, 0.04486737, 0.01504347, 0.10941853, -0.030302342, -0.07639, 0.026978148, -0.09823241, 0.0654905, -0.14902768, 0.11934508, 0.0004743798, -0.00091365026, -0.01855421, -0.010832924]
# ['mountain dew', 'apple juice', 'g2', 'pizza', 'pizza pockets', 'frozen dinners', 'mac and cheese', 'michelena', 'tomato soup', 'ketchup', 'bacon', 'bread', 'popsicles', 'icepop', 'chips', 'gravy & sauce mixes', 'swiss chalet', 'frozen fruit', 'lucky charms', 'cookies', 'juice boxes', 'gatorade powder']
# [0.043953598, 0.118854575, 0.0029596332, 0.073652886, 0.10751101, 0.06705694, -0.07577959, -0.00086497143, 0.00056519976, 0.11945503, -0.14879787, 0.065211765, -0.098226234, 0.026969178, -0.07652882, -0.030135479, 0.10947218, 0.014994119, 0.044827767, -0.14381678, 0.005071772, 0.01919765, 0.13928577, -0.044648107, -0.013487168, 0.05856882, 0.063367195, -0.060200453, 0.071819425, 0.019456996, 0.014612451, -0.21873064, -0.03926334, -0.034825645, -0.019704735, -0.017955396, 0.047138248, 0.17186679, 0.099031076, -0.266429, -0.100292906, 0.08752069, -0.03239409, 0.11059591, 0.0030189597, 0.0071744127, -0.23778293, 0.026043918, -0.03178118, 0.091246545, -0.007362765, 0.14856854, -0.14906609, 0.035576303, -0.010869032]
# ['odouls', 'take out cutlery', 'cutlery', 't shirt bags', 'small ziplock', 'plastic bags', 'dawn', 'ground beef', 'greek', 'tartar', 'chipotle dressing', 'chipotle', 'forty creek bbq', 'white vinegar', 'malt vinegar', 'apple cider vinegar', 'vinegar', 'ranch', 'bbq', 'franks', 'worchestershire sauce', 'worchestershire', 'brown sugar', 'lemon juice', 'coconut milk', 'corn', 'corn frozen', 'frozen peas', 'frozen corn', 'ice cream', 'cheesecake', 'german chocolate cake', 'spring rolls', 'chicken fingers', 'chicken fillets', 'sweet potato fries', 'fries', 'whipping cream', 'sour crema', 'sour cream', 'creamers', 'milk', 'cheddar cheese', 'romaine', 'green onions', 'red peppers', 'green peppers', 'large tomatoes', 'tomatoes', '12 inch tortillas', 'tortillas', 'spinach', 'limes', 'leaf lettuce', 'mushrooms', 'cauliflowers']
# [-0.013514948, -0.023671674, -0.010839173]
# ['biere', 'jus tomate', 'dattes', 'pizza pochette']
# [-0.023671674, -0.010839173]
# ['naya', 'sauce st hurect', 'frites']
# [-0.013514948, -0.023671674, -0.010839173]
# ['eau', 'fraises entières', 'fraises', 'orange']
# []
# ['san pellegrino']
# [0.014987758, 0.044699874, -0.14454566, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671672, -0.010839172]
# ['dairymilk', 'dairy milk cadbury', 'excel', 'kraft', 'battery', 'tidy', 'laundry detergent', 'laundry', 'pepsi diet', 'pepsi', 'red bull yellow']
# [-0.010771925, 0.06557399, -0.098119535, 0.027374433, -0.07617783, -0.030165847, 0.10966433, 0.0150528215, 0.044557497, -0.14435123, 0.004869285, 0.01925686, 0.13940848, -0.044106863, -0.013722824, 0.0014540831, 0.119387835, 0.0008839184, 0.18899333, 0.08024234, -0.0074354564, 0.14894687, -0.14890182, -0.10266574, -0.008041371, 0.012669385, 0.08685245, -0.098728165, 0.11877684, 0.00300478, 0.074589424, 0.108570665, 0.06738998, -0.07076712, -0.010566773]
# ['mars', 'skittles', 'stride', 'fisherman', 'triple push pop', 'push pop', 'surprise', 'bottle pop', 'baby bottle', 'ritz', 'cracker', 'luch on', 'oreo', 'oriville', 'bits cheese cracker sandwiches', 'bits & bites', 'paper towel', 'power steering', 'oil', '10w30', 'peach', 'cut wax', 'vinegar', 'ziplock', 'allens', 'tetley', 'tea', 'betty crocker', 'sundae', 'twin sugar', 'clamato', 'cream', 'table cream', 'auto', 'engine', 'candy']
# [0.14862445, -0.013544901, -0.044613734, 0.13889168, 0.019688107, 0.0048411507, -0.14455226, 0.04490443, -0.09576736, -0.13429946, 0.12813479, -0.07639, 0.02703633, -0.098247066, 0.06543887, -0.14900543, 0.1193726, 0.00047561486, 0.09731776, 0.07963361]
# ['red bull', 'toilet paper', 'eggs', 'meat', 'cereal, granola & bars', 'trail mix', 'flower', 'frozen pizza', 'red rain', 'candy', 'gum', 'pasta', 'wheels', 'diced tomatoes', 'cheese', 'italian seasoning', 'pepperoni', 'bread', 'chill', 'baking', 'cakes & desserts']
# []
# ['skittles']
# [0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['san benedetto', 'perrier', 'evian', 'bocconcini', 'wheat thins', 'crackers', 'cheese crackers']
# [0.109524556, 0.015015273, 0.044671305, -0.14454001, 0.004852889, 0.019152299, 0.13887985, -0.044132903, -0.013432669, -0.02365179, -0.01088622]
# ['san benedetto', 'ripple unsweetened', 'lunch bag', 'frozen pizza', 'arugula', 'hello bello wipes', 'hello bello size 5', 'water wipes', 'hello bello wasb', 'fruit', 'berry jam', 'pudding']
# [0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['sprite', 'spriz up', 'cat litter', 'chicken wings', 'sweet chili chicken wings', 'oragel', 'cabbage', 'saurkraut']
# [0.13887985, -0.04461707, -0.013514948, -0.023671674, -0.010839173]
# ['zero sprite', 'waffles & pancakes', 'eggo', '7up', 'drumstick', 'nestea zero']
# [0.014987758, 0.044699874, -0.14454566, 0.0048425104, 0.019152299, 0.13887985, -0.04461707, -0.013514948, -0.023671672, -0.010839172]
# ['sprite', 'salad dressing', 'bread', 'oatmeal', 'nescafe', 'juice', 'golden temple', 'jam', 'cheese', 'chips & snacks', 'chicolate']
# [-0.22729617, -0.013550967, -0.044588435, 0.13887683, 0.01965471, 0.0047989488, -0.14453398, 0.045199446, 0.015039983, -0.13429186, 0.008322228, -0.16288689, 0.026978975, -0.098226994, 0.06558993, -0.1490341, 0.1193161, 0.0005026174, -0.00091365026, -0.075938635, 0.1489742, 0.09305835]
# ['michelob ultra', 'gain', 'gain feuilles assouplissantes', 'hot dog', 'bleuets', 'porc haché', 'biscuits a lerable', 'erable', 'fraise', 'pain hot dog', 'spaghetti', 'spaghettini', 'macaroni', 'soupe tomate', 'boeuf ache', 'chips', 'salsa', 'recette pub lanieres poulet, entièrement cuits', 'frite', 'framboises', 'pain', 'pain ditaliano', 'tartinade de jambon']
# [-0.010839173]
# ['eska', 'bubly']
# ...
# []
# ['astro plain yogurt 0%']
# []
# ['cornstarch']
# []
# ['piment']
# []
# ['hot wheels 20 cars']
# []
# ['cotton swabs']
# []
# ['baked chips']
# []
# ['mascarpone']
# []
# ['tomato paste']
# []
# ['cheese blocks']
# []
# ['apples']
# []
# ['fromage balderson']
# []
# ['rice']
# []
# ['woolite 16 oz']
# []
# ['mussel']
# []
# ['shitake']
# []
# ['scrub pads']
# []
# ['chicken']
# []
# ['maple sugar']
# []
# ['wagh bakri tea']
# []
# ['cereal']
# []
# ['ackee']
# []
# ['granulated sugar']
# []
# ['ziploc']
# []
# ['pina colada']
# []
# ['food color']
# []
# ['kettlebells']
# []
# ['becel']
# []
# ['500ml jars']
# []
# ['laffy taffy']
# []
# ['deals']
# []
# ['vim cream']
# []
# ['coconut cookies']
# []
# ['monster energy']
# []
# ['oreo']
# []
# ['peppers']
# []
# ['tumbler']
# []
# ['oikos']
# []
# ['beurre amande noisette']
# []
# ['onion']
# []
# ['pb and me']
# []
# ['baby monitor']
# []
# ['uncrustables']
# []
# ['once upon a farm']
# []
# ['feminine hygiene']
# []
# ['coleslaw']
# []
# ['pepperoni']
# []
# ['price match']
# []
# ['washable markers']
# []
# ['ice cream sandwich']
# []
# ['naan']
# []
# ['oreo']
# []
# ['low sodium club soda']
# []
# ['pampers']
# []
# ['cake mix']
# []
# ['sistema container']
# []
# ['flannel twin sheet']
# []
# ['bic lighter']
# []
# ['frutti']
# []
# ['hello toothpaste']
# []
# ['braun age precision digital thermometer']
# []
# ['yogurt']
# []
# ['teeth whitening']
# []
# ['cake decorating']
# []
# ['manicotti']
# []
# ['curry paste']
# []
# ['jars']
# []
# ['tide free powder']
# []
# ['salmon']
# []
# ['apple air pods']
# []
# ['cassonade']
# []
# ['dishwasher tab']
# []
# ['pork back ribs']
# []
# ['shirataki noodles']
# []
# ['ribena']
# []
# ['paneer']
# []
# ['cake']
# []
# ['turmeric force']
# []
# ['granola bars']
# []
# ['candles']
# []
# ['halibut']
# []
# ['pizza pops']
# []
# ['nature clean soap']
# []
# ['dessert stands']
# []
# ['bologna']
# []
# ['wine']
# []
# ['miso']
# []
# ['neutrogena body']
# []
# ['bacon']
# []
# ['lava']
# []
# ['butter']
# []
# ['jamieson blueberry']
# []
# ['vanilla cupcakes']
# []
# ['shower curtains']
# []
# ['stewing beef']
# []
# ['sour cream glaze']
# []
# ['cauliflower rice']
# []
# ['chocolate chips']
# []
# ['frozen peaches']
# []
# ['pizza']
# []
# ['sparkling water']
# []
# ['depends']
# []
# ['cheese']
# []
# ['voltaren emulgel']
# []
# ['confitures et tartinades sucrées']
# []
# ['numi']
# []
# ['pampers size 5']
# []
# ['walnuts']
# []
# ['masks']
# []
# ['special k']
# []
# ['maille vinaigrette']
# []
# ['canned tuna']
# []
# ['international delight']
# []
# ['apple']
# []
# ['chicken drumsticks']
# []
# ['cookies']
# []
# ['hot sauce']
# []
# ['can opener']
# []
# ['potatoes']
# []
# ['baskets']
# []
# ['lays chips']
# []
# ['pumpkin']
# []
# ["kellogg's cereal"]
# []
# ['sardine']
# []
# ['soppressata thin sliced']
# []
# ['chicken legs back attached']
# []
# ['dark chocolate']
# []
# ['vegan butter']
# []
# ['mug']
# []
# ['egg']
# []
# ['ramen noddle']
# []
# ['hot pepper']
# []
# ['household cleaners']
# []
# ['chicken']
# []
# ['rib eye']
# []
# ['dove deodorant']
# []
# ['coffee maker']
# []
# ['parchment muffin cups']
# []
# ['v8 cocktail']
# []
# ['parathas']
# []
# ['unsalted butter']
# []
# ['hardbite']
# []
# ['maggi sauce']
# []
# ['stevia']
# []
# ['oranges']
# []
# ['laxaday']
# []
# ['utensil holder']
# []
# ['hair spray']
# []
# ['prime rib roast']
# []
# ['water']
# []
# ['halloween candy']
# []
# ['nicoderm']
# []
# ['hangar']
# []
# ['canned tuna']
# []
# ['huile coco']
# []
# ['mozzarella']
# []
# ['tikka']
# []
# ['m&ms']
# []
# ['table consol']
# []
# ['vitimin d']
# []
# ['sidekicks']
# []
# ['facial tissue']
# []
# ['peach, plum & nectarines']
# []
# ['dulcolax']
# []
# ['cereal']
# []
# ['corn squares']
# []
# ['crispy oninos']
# []
# ['marbled cheese']
# []
# ['salmon']
# []
# ['honey bunches of oats almond with 25% more almonds cereal']
# []
# ['salsa']
# []
# ['beets']
# []
# ['broad beans']
# []
# ['gluten free pizza']
# []
# ['all bran']
# []
# ['ham slices']
# []
# ['kraft parmesan cheese']
# []
# ['tortillas']
# []
# ['bras']
# []
# ['macaroni']
# []
# ['floor pillow']
# []
# ['advent']
# []
# ['organic face wash']
# []
# ['ensure']
# []
# ['nutrasea']
# []
# ['floor cushion']
# []
# ['andalou']
# []
# ['larsen wieners']
# []
# ['haddock']
# []
# ['gound beef']
# []
# ['duration gel']
# []
# ['pull ups']
# []
# ['gaterade zero']
# []
# ['dawn dish']
# []
# ['water 4l']
# []
# ['couscous']
# []
# ['dishwasher tabs']
# []
# ['bolognese']
# []
# ['greek yogurt']
# []
# ['phstmacy phone number']
# []
# ['sweet potato']
# []
# ['japanese green tea']
# []
# ['eggs']
# []
# ['kitchens of india']
# []
# ['masks']
# []
# ['bao']
# []
# ['oxi']
# []
# ['special k']
# []
# ['labneh']
# []
# ['pasta shells']
# []
# ['pc blue menu bread']
# []
# ['charmin']
# []
# ['vanilla ice cream']
# []
# ['butterball turkey']
# []
# ['bladerson cheese']
# []
# ['chocolate wafers']
# []
# ['chapmans ice cream sundae']
# []
# ['salad']
# []
# ['thai kitchen']
# []
# ['spinach pasta']
# []
# ['sturgeon falls']
# []
# ['finesse']
# []
# ['seventh generation']
# []
# ['shrimp']
# []
# ['canada hats']
# []
# ['apples']
# []
# ['rice crackers']
# []
# ['method']
# []
# ['biscuits']
# []
# ['pam cooking spray']
# []
# ['greenfields bacon']
# []
# ['coffee']
# []
# ['flax seeds']
# []
# ['shrimp crackers']
# []
# ['tomato paste']
# []
# ['matcha latte']
# []
# ['gloves']
# []
# ['all vegetable shortening']
# []
# ['alien']
# []
# ['bento box']
# []
# ['paper towel']
# []
# ['frozen blueberries']
# []
# ['boys shoes']
# []
# ['charmin']
# []
# ['veggie crisps']
# []
# ['ortho']
# []
# ['slippers']
# []
# ['potatoes patties']
# []
# ['palmolive']
# []
# ['gateau']
# []
# ['clr']
# []
# ['cheese']
# []
# ['halal']
# []
# ['red lobster']
# []
# ['m & m']
# []
# ['condom']
# []
# ['mustard']
# []
# ['pepper sauce']
# []
# ['red kidney beans']
# []
# ['lara bar']
# []
# ['potato salad']
# []
# ['nespresso pods']
# []
# ['peppers']
# []
# ['paper towel']
# []
# ['farmer’s market']
# []
# ['listerine strips']
# []
# ['bird suet']
# []
# ['pumpkin spice']
# []
# ['hot dog']
# []
# ['linges et serviettes à vaisselle']
# []
# ['strawberry jam']
# []
# ['face care']
# []
# ['oreo']
# []
# ['knorr peppercorn sauce']
# []
# ['cheerios']
# []
# ['bento box']
# []
# ['skim milk']
# []
# ['pc plant based']
# []
# ['pepperidge farm']
# []
# ['homo milk']
# []
# ['cool whip']
# []
# ['natural baby diapers']
# []
# ['the decadent']
# []
# ['salmon']
# []
# ['high liner']
# []
# ['milk 2%']
# []
# ['eggs']
# []
# ['bissell']
# []
# ['daiya pizza']
# []
# ['plant based snack']
# []
# ['1 4 slab']
# []
# ['cauliflower']
# []
# ['cushion']
# []
# ['udi']
# []
# ['compression socks']
# []
# ['parmesan']
# []
# ['protein powder']
# []
# ['sweet potato fries']
# []
# ['chicken']
# []
# ['dove']
# []
# ['disposable mask']
# []
# ['welo']
# []
# ['shrimp ring']
# []
# ['pringles']
# []
# ['cilantro']
# []
# ['half and half']
# []
# ['glutin free snacks']
# []
# ['blueberries']
# []
# ['magic eraser durable']
# []
# ['cranberry juice']
# []
# ['cell phones & accessories']
# []
# ['can opener']
# []
# ['coconut kefir']
# []
# ['oil']
# []
# ['argon oil']
# []
# ['grapes']
# []
# ['lime']
# []
# ['towels']
# []
# ['frozen dinners']
# []
# ['lysol']
# []
# ['chicken']
# []
# ['takis']
# []
# ['ice cream']
# []
# ['black rice']
# []
# ['espresso machine']
# []
# ['joe fresh baby boy']
# []
# ['chicken breast']
# []
# ['ginger juice']
# []
# ['listerine cool mint']
# []
# ['french press']
# []
# ['hummus']
# []
# ['milk powder']
# []
# ['sheet mask']
# []
# ['oats']
# []
# ['high chair']
# []
# ['celery seed']
# []
# ['cashmere']
# []
# ['t bone steak']
# []
# ['umbrella']
# []
# ['nectarines']
# []
# ['huggies pull up']
# []
# ['ensure']
# []
# ['tofu']
# []
# ['mayonnaise']
# []
# ['garlic']
# []
# ['rice dream']
# []
# ['indomie']
# []
# ['bread']
# []
# ['light bulb']
# []
# ['spaghetti sauce']
# []
# ['sliced turkey']
# []
# ['pine nuts']
# []
# ['spanikopita']
# []
# ['chicken pot pie']
# []
# ['natrel']
# []
# ['rose']
# []
# ['baby wipe']
# []
# ['planter']
# []
# ['aloe vera leaves']
# []
# ['face mask']
# []
# ['huggies size 4']
# []
# ['organic milk']
# []
# ['crisco']
# []
# ['white bread']
# []
# ['cooking spray']
# []
# ['kitchen soap dispenser']
# []
# ['cat tree']
# []
# ['costco mediflow pillow']
# []
# ['baking soda']
# []
# ['flour']
# []
# ['chia seeds']
# []
# ['clif whey']
# []
# ['rice']
# []
# ['romaine']
# []
# ['beef and pork']
# []
# ['barilla pasta']
# []
# ['mala sauce']
# []
# ['starbucks']
# []
# ['jam']
# []
# ['aveeno']
# []
# ['getorade']
# []
# ['clorox bleach']
# []
# ['zucchini']
# []
# ['red river']
# []
# ['tide pods']
# []
# ['centrum']
# []
# ['cerave']
# []
# ['miniral wate']
# []
# ['enfamil']
# []
# ['kitten food']
# []
# ['large ziploc bags']
# []
# ['good start 2']
# []
# ['cookie cutters']
# []
# ['creme fraiche']
# []
# ['strawberries']
# []
# ['rexal soap']
# []
# ['creamer']
# []
# ['mountain dew']
# []
# ['johnsonville sausage']
# []
# ['resolve']
# []
# ['pumpkin puree']
# []
# ['gatorade']
# []
# ['head to toe wash']
# []
# ['tide pods']
# []
# ['milk']
# []
# ['omega 3 jamieson']
# []
# ['cucumber']
# []
# ['blackberries']
# []
# ['milk carton']
# []
# ['toms toothpaste']
# []
# ['raspbberies']
# []
# ['clamato']
# []
# ['diced tomato']
# []
# ['paper plates']
# []
# ['kuerig']
# []
# ["newman's own"]
# []
# ['presidents choice hot wings']
# []
# ['moon cake']
# []
# ['coconut water']
# []
# ['spiral ham']
# []
# ['organic milk']
# []
# ['roger']
# []
# ['vinegar']
# []
# ['always']
# []
# ['dealcoholized wine']
# []
# ['halloween candy']
# []
# ['microban']
# []
# ['facemask']
# []
# ['lemon juice']
# []
# ['pc ribs']
# []
# ['chips']
# []
# ['honey crisp apples']
# []
# ['betadine']
# []
# ['lettuce']
# []
# ['tomato sauce with no sugar']
# []
# ['bratwurst sausage']
# []
# ['oranges']
# []
# ['bean sprouts']
# []
# ['masque']
# []
# ['astro']
# []
# ['seafood']
# []
# ['mango juice']
# []
# ['kd']
# []
# ['p’tit\xa0québec']
# []
# ['eucalyptus']
# []
# ['laundry soap']
# []
# ['tzatziki']
# []
# ['chicken breast']
# []
# ['burgers']
# []
# ['furniture love seat']
# []
# ['farmers market mandarin']
# []
# ['sour cream']
# []
# ['dr teals']
# []
# ['cheese']
# []
# ['chocolate cake']
# []
# ['basmati']
# []
# ['frozen vegetables']
# []
# ['moon cake']
# []
# ['butterball']
# []
# ['fudge']
# []
# ['rice noodles']
# []
# ['hengstenberg']
# []
# ['bed sheets']
# []
# ['chicken tacos']
# []
# ['buckwheat flour']
# []
# ['cranberry juice']
# []
# ['krill']
# []
# ['coffee folgers']
# []
# ['earths own']
# []
# ['cashew butter']
# []
# ['cumin']
# []
# ['fever tree']
# []
# ['ail']
# []
# ['gluten free cake']
# []
# ['tim hortons']
# []
# ['bread']
# []
# ['matcha']
# []
# ['carrot']
# []
# ['organic broth']
# []
# ['halloween']
# []
# ['rimmel powder']
# []
# ['fruit snacks']
# []
# ['xlear']
# []
# ['cake']
# []
# ['sukrin gold']
# []
# ['poivrons']
# []
# ['sprite']
# []
# ['chicken']
# []
# ['riz sushi']
# []
# ['frosting']
# []
# ['bissell']
# []
# ['jus']
# []
# ['white dining chairs']
# []
# ['dr oetker pizza']
# []
# ['pumpkin carving']
# []
# ['dumplings']
# []
# ['lays potato chips']
# []
# ['powder milk']
# []
# ['cooked pasta']
# []
# ['nut butter']
# []
# ['sloppy joe']
# []
# ['gillette fusion proglide sensitive 2 in 1 shave gel, ocean breeze 170.0g']
# []
# ['pommes']
# []
# ['pineapple tidbits']
# []
# ['chou fleur']
# []
# ['backpack']
# []
# ['wow butter']
# []
# ['frozen blueberrues']
# []
# ['sambucol']
# []
# ['pea pods']
# []
# ['olive oil']
# []
# ['carrots']
# []
# ['ranch']
# []
# ['blueberries']
# []
# ['dot candy']
# []
# ['gluten free']
# []
# ['weight watchers bread']
# []
# ['parmesan']
# []
# ['ticket to ride']
# []
# ['electrolyte']
# []
# ['light bulb']
# []
# ['soozier pad']
# []
# ['keto bone broth']
# []
# ['mini potatoes']
# []
# ['postage stamps']
# []
# ['organic raisins']
# []
# ['sugar twin']
# []
# ['le gaspesien']
# []
# ['litière']
# []
# ['sidekicks']
# []
# ['noix cajou']
# []
# ['egg']
# []
# ['wheat free']
# []
# ['zuchinni']
# []
# ['baby gourmet']
# []
# ['extra strength ibuprofen 400mg']
# []
# ['drink mix']
# []
# ['tofu dessert']
# []
# ['halo top']
# []
# ['egg']
# []
# ['milk']
# []
# ['chocolate milk']
# []
# ['jus oasis']
# []
# ['aaa batteries']
# []
# ['culligan']
# []
# ['peppers']
# []
# ['prenatal']
# []
# ['fiji water']
# []
# ['lemongrass']
# []
# ['dog treats']
# []
# ['cauliflower']
# []
# ['ginger beer']
# []
# ['christmas tree']
# []
# ['silicone cup']
# []
# ['schneiders genoa salami']
# []
# ['cotton balls']
# []
# ['persil']
# []
# ['lime juice']
# []
# ['moon cake with white lotus paste']
# []
# ['pc chocolate']
# []
# ['toilet tissue']
# []
# ['coffee beans']
# []
# ['sensodyne']
# []
# ['chicken thighs']
# []
# ['graine de chanure']
# []
# ['chicken & turkey']
# []
# ['catan']
# []
# ['post']
# []
# ['ice cream']
# []
# ['eau gazeuse']
# []
# ['black garlic']
# []
# ['sugar']
# []
# ['porc']
# []
# ['toy trucks']
# []
# ['ravioli']
# []
# ['untortilla']
# []
# ['tomato']
# []
# ['smoked salmon']
# []
# ['davids killer bread']
# []
# ['cake']
# []
# ['pastrami']
# []
# ['nata de coco']
# []
# ['fancy molasses']
# []
# ['provigo']
# []
# ['brita']
# []
# ['fruit cups']
# []
# ['veggie burgers']
# []
# ['fluoride free toothpaste']
# []
# ['roasted red pepper']
# []
# ['flushable wipes']
# []
# ['gatorade']
# []
# ['bio oil']
# []
# ['keto stream']
# []
# ['frozen dessert']
# []
# ['liberte']
# []
# ['chicken breast']
# []
# ['tissue']
# []
# ['dates']
# []
# ['nutpods']
# []
# ['starbucks']
# []
# ['simply orange']
# []
# ['brown sugar']
# []
# ['rubbing alcholol']
# []
# ['yogurt']
# []
# ['casa']
# []
# ['advil']
# []
# ['herring']
# []
# ['dinnerware']
# []
# ['rice']
# []
# ['pc lasagna']
# []
# ['maple candy']
# []
# ['ladies pajamas']
# []
# ['monster energy']
# []
# ['cat litter']
# []
# ['fondue cheese']
# []
# ['splenda stevia sweetener']
# []
# ['chicken burgers']
# []
# ['oatmeal']
# []
# ['miss vickies']
# []
# ['ground pork']
# []
# ['pepper']
# []
# ['mozzarella']
# []
# ['deli turkey']
# []
# ['chow mein noodle']
# []
# ['organic white rice']
# []
# ['frozen potatoes']
# []
# ['frozen pizza dough']
# []
# ['shirataki noodles']
# []
# ['flour']
# []
# ['floor cushion']
# []
# ['old el paso']
# []
# ['learning tower']
# []
# ['mini chocolate bars']
# []
# ['raisins']
# []
# ['dawn dish soap']
# []
# ['pillow']
# []
# ['zevia']
# []
# ['rice']
# []
# ['dates']
# []
# ['b12 tea']
# []
# ['new york kosher dills']
# []
# ['toilet paper']
# []
# ['rubble']
# []
# ['oranges']
# []
# ['dofino havarti']
# []
# ['crevette']
# []
# ['counter stools']
# []
# ['dutch crunch']
# []
# ['green curry paste']
# []
# ['cream of celery']
# []
# ['bounce']
# []
# ['pâtes rotini']
# []
# ['hamburg buns']
# []
# ['e giftcard']
# []
# ['toilet paper']
# []
# ['bandages']
# []
# ['power bowl']
# []
# ['milk']
# []
# ['cough drops']
# []
# ['tomate']
# []
# ['tenderflake']
# []
# ['mayonnaise']
# []
# ['powerade']
# []
# ['chicken']
# []
# ['becel']
# []
# ['eggs']
# []
# ['bottle']
# []
# ['aylmer']
# []
# ['pork bacon']
# []
# ['sushi rice']
# []
# ['liberte greek yogurt']
# []
# ['peanut free']
# []
# ['club house cream of tartar']
# []
# ['toilet paper']
# []
# ['boys rain boot']
# []
# ['chicken wings']
# []
# ['chiobani']
# []
# ['iogo yogurt']
# []
# ['outsunny']
# []
# ["dave's killer"]
# []
# ['asian salad']
# []
# ['beef short rib']
# []
# ['black forest ham']
# []
# ['yogurt']
# []
# ['thermal rolls']
# []
# ['bento snack box']
# []
# ['unico vegetable oil']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4059baec077f> in <module>
#       3 for i in range(len(json_df)):
#       4     vocab = json_df.values[i][0]    # creating vocab
# ----> 5     model = Word2Vec([vocab], min_count = 1)   # training model
#       6     score, sim = [],[]
#       7     k = len(vocab)
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in __init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     428                 corpus_iterable=corpus_iterable, corpus_file=corpus_file, total_examples=self.corpus_count,
#     429                 total_words=self.corpus_total_words, epochs=self.epochs, start_alpha=self.alpha,
# --> 430                 end_alpha=self.min_alpha, compute_loss=self.compute_loss, callbacks=callbacks)
#     431         else:
#     432             if trim_rule is not None:
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1071                     corpus_iterable, cur_epoch=cur_epoch, total_examples=total_examples,
#    1072                     total_words=total_words, queue_factor=queue_factor, report_delay=report_delay,
# -> 1073                     callbacks=callbacks, **kwargs)
#    1074             else:
#    1075                 trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch_corpusfile(
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in _train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay, callbacks)
#    1427         for thread in workers:
#    1428             thread.daemon = True  # make interrupting the process with ctrl+c easier
# -> 1429             thread.start()
#    1430
#    1431         trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#
# ~\Anaconda3\lib\threading.py in start(self)
#     855                 del _limbo[self]
#     856             raise
# --> 857         self._started.wait()
#     858
#     859     def run(self):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Update dataframe with Similarity Score and Classification (similar/not similar)
# ### I used a threshold of 50% similarity between consecutive terms irrespective of direction (orthogonal/diametrically opposite/same)

# %%
df = json_df.copy()  # Creating dataframe df and adding comments columns to indicate similarity
#df
df["Similarity Score"] = " "
df["Classification Comments"] = " "
df.head()
# Out:
#                                            query_arr  \
# 0                                     [water bottle]
# 1  [eau de source, nutella, huile d’olive, chou f...
# 2  [coffee crisp, coffee, kinder, beuno, salad, b...
# 3  [water, canned drinks, soda, hot dog buns, hot...
# 4                           [eau, jus de canneberge]
#
#                                         atc_item_arr  \
# 0                                       [20005571_C]
# 1  [20005571_C, 20436105_EA;20574189_EA, 20729461...
# 2  [20019964_C, 20050931_EA, NO PRODUCT, NO PRODU...
# 3  [20022126_C, 20375155_C, 20306687003_C, 207799...
# 4                           [20022126_C, NO PRODUCT]
#
#                                        timestamp_arr  \
# 0                                       [1631528381]
# 1   [1631756371, 1631756422, 1631756501, 1631756536]
# 2  [1631542818, 1631542869, 1631545955, 163154598...
# 3  [1631721943, 1631721964, 1631722025, 163172207...
# 4                           [1631736981, 1631736999]
#
#                               sessionid Similarity Score  \
# 0  5ef0c4fd-31ae-4b60-adc3-ee0cf645c812
# 1  50534a81-5abe-4b66-be56-c767ee28acfc
# 2  0f10758d-f4c6-4ec4-9a86-08e353a9c221
# 3  e60e1c97-a7fc-46d3-af58-cc2f3de4b2f9
# 4  bb672d6d-fddc-4a9e-a898-6bd3f4bc8e78
#
#   Classification Comments
# 0
# 1
# 2
# 3
# 4

# %%
# 4. Consecutive queries compared and similarity score produced for ** first 10 sessions ***
from gensim.models import Word2Vec
for i in range(10):
    vocab = df.values[i][0]    # creating vocab
    model = Word2Vec([vocab], min_count = 1)   # training model
    score, sim = [],[]
    k = len(vocab)
    for j in range(k-1):
        ls = model.wv.similarity(vocab[j],vocab[j+1])  # analyzing model
        if abs(ls) < 0.5:      # threshold of 50% similarity irrespective of direction (orthogonal/diametrically opposite/same)
            ls1 = 'not similar'
        else:
            ls1 = 'similar'
        score.append(ls)
        sim.append(ls1)
    df["Similarity Score"][i] = score
    df["Classification Comments"][i] = sim #np.where(df["Classification Comments"][i] < 0.5,'not similar','similar')
df.head(10)
# Out:
#                                            query_arr  \
# 0                                     [water bottle]
# 1  [eau de source, nutella, huile d’olive, chou f...
# 2  [coffee crisp, coffee, kinder, beuno, salad, b...
# 3  [water, canned drinks, soda, hot dog buns, hot...
# 4                           [eau, jus de canneberge]
# 5  [case of water, grapefruit, grapefruit juice, ...
# 6                       [water, butter, fruit packs]
# 7  [water, tide, garbage bags, pantene, polident,...
# 8  [water, orange juice, apple juice, pepperoni, ...
# 9  [water, epsom salts, garlic, cotton balls, cot...
#
#                                         atc_item_arr  \
# 0                                       [20005571_C]
# 1  [20005571_C, 20436105_EA;20574189_EA, 20729461...
# 2  [20019964_C, 20050931_EA, NO PRODUCT, NO PRODU...
# 3  [20022126_C, 20375155_C, 20306687003_C, 207799...
# 4                           [20022126_C, NO PRODUCT]
# 5  [20022126_C, NO PRODUCT, 21209809_EA, NO PRODU...
# 6          [20022126_C, 20118993_EA, 20075199001_EA]
# 7  [20022126_C, 20751974_EA, 20052479_EA, 2090667...
# 8  [20022126_C, 20883056_EA, 20501952_EA, 2018984...
# 9  [20022126_C, 21256700_EA, 21004355001_EA, NO P...
#
#                                        timestamp_arr  \
# 0                                       [1631528381]
# 1   [1631756371, 1631756422, 1631756501, 1631756536]
# 2  [1631542818, 1631542869, 1631545955, 163154598...
# 3  [1631721943, 1631721964, 1631722025, 163172207...
# 4                           [1631736981, 1631736999]
# 5  [1631714854, 1631714871, 1631714878, 163171494...
# 6               [1631568918, 1631569330, 1631569367]
# 7  [1631568745, 1631568779, 1631568814, 163156886...
# 8  [1631750390, 1631750446, 1631750474, 163175054...
# 9  [1631748364, 1631748375, 1631748387, 163174840...
#
#                               sessionid  \
# 0  5ef0c4fd-31ae-4b60-adc3-ee0cf645c812
# 1  50534a81-5abe-4b66-be56-c767ee28acfc
# 2  0f10758d-f4c6-4ec4-9a86-08e353a9c221
# 3  e60e1c97-a7fc-46d3-af58-cc2f3de4b2f9
# 4  bb672d6d-fddc-4a9e-a898-6bd3f4bc8e78
# 5  efb2afbf-3389-4054-9e9e-fc68495144c2
# 6  8b392055-e827-4726-b538-f9e6dd57591e
# 7  a44568e2-0755-46a7-b294-e1f106d5389c
# 8  9d29cbcf-67e3-4652-91c7-17680459e33e
# 9  e22aa53d-e1d9-4375-b89d-c69446d88eb7
#
#                                     Similarity Score  \
# 0                                                 []
# 1         [-0.013514948, -0.023671674, -0.010839173]
# 2  [0.13887985, -0.04461707, -0.013514948, -0.023...
# 3  [0.0038111245, -0.0009846962, 0.0003889287, 0....
# 4                                     [-0.010839173]
# 5  [-0.030296177, 0.10960891, 0.014882498, 0.0446...
# 6                       [-0.023671674, -0.010839173]
# 7  [0.019152299, 0.13887985, -0.04461707, -0.0135...
# 8  [-0.11228521, -0.013413804, -0.04451552, 0.138...
# 9  [0.109524556, 0.015015273, 0.044671305, -0.144...
#
#                              Classification Comments
# 0                                                 []
# 1            [not similar, not similar, not similar]
# 2  [not similar, not similar, not similar, not si...
# 3  [not similar, not similar, not similar, not si...
# 4                                      [not similar]
# 5  [not similar, not similar, not similar, not si...
# 6                         [not similar, not similar]
# 7  [not similar, not similar, not similar, not si...
# 8  [not similar, not similar, not similar, not si...
# 9  [not similar, not similar, not similar, not si...

# %% [markdown]
# ## Model Evaluation Ideas

# %% [markdown]
# ### One way to evaluate the word2vec model is to come up with ground truth labels (e.g. Use AWS Amazon SageMaker Ground Truth to Label Data).
# ### Ground truth labels will be words that should be closest together in vector space with largest cosine similarity.
# ### Apply the K-Means algorithm on the features generated by the Word2Vec model. Assuming, we would have created our own manual labels/ground truth representing the instances/records.
# ### We can calculate the accuracy of the model by comparing the clustered result tags generated with the ground truth labels.
# ### Eg: Our kMeans clusters => Clusuter 0 - Positive words; Cluster 1 - Negative words
# ### We can compare the tags/labels generated by the clusters with the ground truth values of the instances/sentences in the clusters and calculate the accuracy.
